# %%
import pandas as pd
import datetime as dt
import backtrader as bt
import quantstats as qs
import matplotlib as plt
import numpy as np
import os
import pathlib
os.getcwd()

#数据加载-------------------------------------
df=pd.read_csv(pathlib.Path.cwd() / ".." / "data"/ "testCSI300.csv")
df.index=pd.to_datetime(df.date)
df['openinterest']=0

#以下是自己随机添加signal的之后的文件，hmm算法给出的带signal的文件直接用上面的df=pd.read_csv导入，把下面到构建策略之前mute掉即可

# 随机生成一个-1，0，1的predictions序列---------
# sig=[]
# for i in range(len(df)):
#     x=np.random.randn()
#     if x > 0.2:
#         sig.append(1)
#     elif x<-0.2:
#         sig.append(-1)
#     else:
#         sig.append(0)
# df['signal']=sig



#构建策略-------------------------------------
class TestSignalStrategy(bt.Strategy):
    params=()

    def log(self,txt,dt=None):
        dt= dt or self.datetime.date(0)
        print('%s,%s' % (dt.isoformat(),txt)) 

    def __init__(self):
        self.bar_num=0
        self.signal_df=df
        self.signal_df['date']=pd.to_datetime(self.signal_df['date'])
        self.first_trade=True

    def prenext(self):
        self.next()

    def next(self):
        self.bar_num+=1
        current_date=self.datas[0].datetime.date(0).strftime("%Y-%m-%d")
        try:
            next_date =self.datas[0].datetime.date(1)
        except:
            next_date=None
        if next_date != None:
            next_signal_df= self.signal_df[self.signal_df['date']==pd.to_datetime(next_date)]
            if len(next_signal_df)==0:
                self.log("下个交易日的信号不存在")
            else:
                signal = int(next_signal_df['signal'])
                
                #第一次交易没有底仓，只允许做多
                #交易信号的执行方式：
                #先不考虑卖空
                #signal为1，以当天开盘价全仓买入
                #signal为-1时，以当天开盘价卖出所有持仓
                if self.first_trade:
                    if signal==-1:
                        pass
                    if signal == 1:
                        total_value = self.broker.get_value()
                        open_price = self.datas[0].open[0]
                        target_size=total_value//open_price
                        self.buy(self.datas[0],size=target_size,price=open_price)
                        self.first_trade=False
                else:
                    #现有持仓
                    now_hold_size = self.getposition(self.datas[0]).size
                    if signal == 1:
                        total_value = self.broker.get_value()
                        open_price = self.datas[0].open[0]
                        target_size=total_value//open_price
                        self.buy(self.datas[0],size=target_size, price=open_price)

                    if signal == -1:
                        total_value = self.broker.get_value()
                        open_price = self.datas[0].open[0]
                        target_size=total_value//open_price
                        #卖出开仓，手数不能超过底仓
                        if target_size>now_hold_size:
                            target_size=now_hold_size

                        self.sell(self.datas[0],size=target_size, price=open_price)

    #订单情况
    def notify_order(self, order):
        
        #订单处于未决，继续
        if order.status in [order.Submitted, order.Accepted]:
            return
        
        #订单已决
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log('买单执行,%.2f' % order.executed.price)

            elif order.issell():
                self.log('卖单执行,%2f' % order.executed.price)
        
        elif order.status in [order.Canceled,order.Rejected,order.Expired]:
            self.log('订单 Canceled/Rejected/Expired')

    #交易情况
    def notify_trade(self, trade):
        if trade.isclosed:
            print('毛收益 %0.2f, 扣佣后收益 % 0.2f , 佣金 %.2f'
            % (trade.pnl, trade.pnlcomm, trade.commission))
        


cerebro=bt.Cerebro()

stock_df=df[['open','high','low','close','volume','openinterest']]

# %%
data=bt.feeds.PandasData(dataname=stock_df,fromdate=dt.datetime(2014, 3, 7), todate=dt.datetime(2021, 12, 30),timeframe=bt.TimeFrame.Days)
cerebro.adddata(data)

#滑点设置 0.5%
cerebro.broker = bt.brokers.BackBroker(slip_perc=0.005)
#初始资金设置为10万
cerebro.broker.setcash(100000.0)
#手续费万分之二
cerebro.broker.setcommission(commission=0.0002)

cerebro.addstrategy(TestSignalStrategy)
cerebro.addanalyzer(bt.analyzers.PyFolio,_name='PyFolio')

#运行回测
print('start portfolio value:',format(cerebro.broker.getvalue()))
results = cerebro.run()
print('end portfolio value:',format(cerebro.broker.getvalue()))


#绩效评价----------------------------
#获取策略实例
start = results[0]
portfolio_stats = start.analyzers.getbyname('PyFolio')
#以下returns为以日期为索引的资产日收益率序列
returns,positions,transactions,gross_lev = portfolio_stats.get_pf_items()
returns.index = returns.index.tz_convert(None)
# Out:
# start portfolio value: 100000.0
# 2014-03-25,买单执行,2170.78
# 2014-04-04,卖单执行,2157.980000
# 2014-04-21,卖单执行,2209.940000
# 毛收益 -536.84, 扣佣后收益 -576.67 , 佣金 39.83
# 2014-05-14,买单执行,2175.09
# 2014-05-22,卖单执行,2134.090000
# 毛收益 -1845.00, 扣佣后收益 -1883.78 , 佣金 38.78
# 2014-05-30,买单执行,2156.38
# 2014-06-05,卖单执行,2126.610000
# 毛收益 -1309.88, 扣佣后收益 -1347.57 , 佣金 37.69
# 2014-06-13,买单执行,2150.99
# 2014-06-20,卖单执行,2124.960000
# 毛收益 -1145.32, 扣佣后收益 -1182.95 , 佣金 37.63
# 2014-07-02,买单执行,2164.00
# 2014-07-11,卖单执行,2136.320000
# 毛收益 -1190.24, 扣佣后收益 -1227.22 , 佣金 36.98
# 2014-07-21,买单执行,2164.22
# 2014-08-15,卖单执行,2337.990000
# 2014-08-18,卖单执行,2366.270000
# 毛收益 7500.39, 扣佣后收益  7461.67 , 佣金 38.72
# 2014-08-19,买单执行,2378.89
# 2014-08-27,卖单执行,2323.790000
# 毛收益 -2314.20, 扣佣后收益 -2353.70 , 佣金 39.50
# 2014-09-09,买单执行,2452.23
# 2014-09-17,卖单执行,2395.360000
# 2014-09-18,卖单执行,2396.380000
# 毛收益 -2273.78, 扣佣后收益 -2312.56 , 佣金 38.78
# 2014-09-26,买单执行,2430.81
# 2014-10-20,卖单执行,2448.450000
# 毛收益 687.96, 扣佣后收益  649.90 , 佣金 38.06
# 2014-10-31,买单执行,2473.50
# 2014-11-21,卖单执行,2537.540000
# 毛收益 2497.56, 扣佣后收益  2458.47 , 佣金 39.09
# 2014-11-27,买单执行,2737.03
# 2014-12-18,卖单执行,3359.090000
# 毛收益 22394.16, 扣佣后收益  22350.27 , 佣金 43.89
# 2014-12-19,买单执行,3345.63
# 2014-12-30,卖单执行,3450.810000
# 2014-12-31,卖单执行,3462.390000
# 毛收益 3798.06, 扣佣后收益  3749.12 , 佣金 48.94
# 2015-01-07,买单执行,3620.92
# 2015-01-15,卖单执行,3501.720000
# 毛收益 -4052.80, 扣佣后收益 -4101.23 , 佣金 48.43
# 2015-01-29,买单执行,3474.91
# 2015-02-02,卖单执行,3360.190000
# 毛收益 -3900.48, 扣佣后收益 -3946.96 , 佣金 46.48
# 2015-02-17,买单执行,3511.54
# 2015-03-10,卖单执行,3523.640000
# 毛收益 399.30, 扣佣后收益  352.87 , 佣金 46.43
# 2015-03-16,买单执行,3641.77
# 2015-05-06,卖单执行,4626.230000
# 2015-05-07,卖单执行,4520.820000
# 毛收益 31397.31, 扣佣后收益  31344.42 , 佣金 52.89
# 2015-05-15,买单执行,4690.76
# 2015-06-01,卖单执行,4862.760000
# 毛收益 5332.00, 扣佣后收益  5272.77 , 佣金 59.23
# 2015-06-10,买单执行,5254.30
# 2015-06-17,卖单执行,5072.310000
# 毛收益 -5095.72, 扣佣后收益 -5153.55 , 佣金 57.83
# 2015-07-21,买单执行,4109.76
# 2015-07-22,卖单执行,4148.560000
# 毛收益 1358.00, 扣佣后收益  1300.19 , 佣金 57.81
# 2015-07-27,买单执行,4097.80
# 2015-07-28,卖单执行,3690.970000
# 2015-07-29,卖单执行,3839.960000
# 毛收益 -14090.06, 扣佣后收益 -14144.61 , 佣金 54.55
# 2015-08-12,买单执行,4025.67
# 2015-08-19,卖单执行,3748.270000
# 2015-08-20,卖单执行,3848.400000
# 毛收益 -8953.94, 扣佣后收益 -9005.29 , 佣金 51.35
# 2015-09-08,买单执行,3221.79
# 2015-09-11,卖单执行,3349.880000
# 毛收益 4867.42, 扣佣后收益  4817.48 , 佣金 49.94
# 2015-09-25,买单执行,3272.66
# 2015-09-28,卖单执行,3226.610000
# 2015-09-29,卖单执行,3197.220000
# 毛收益 -1871.39, 扣佣后收益 -1923.38 , 佣金 51.99
# 2015-10-13,买单执行,3422.48
# 2015-11-04,卖单执行,3477.160000
# 2015-11-05,卖单执行,3630.780000
# 毛收益 2231.46, 扣佣后收益  2178.99 , 佣金 52.47
# 2015-11-10,买单执行,3806.67
# 2015-11-19,卖单执行,3725.620000
# 毛收益 -2755.70, 扣佣后收益 -2806.92 , 佣金 51.22
# 2015-12-09,买单执行,3613.42
# 2015-12-14,卖单执行,3573.880000
# 毛收益 -1383.90, 扣佣后收益 -1434.21 , 佣金 50.31
# 2015-12-18,买单执行,3754.96
# 2015-12-31,卖单执行,3760.900000
# 毛收益 201.96, 扣佣后收益  150.85 , 佣金 51.11
# 2016-02-19,买单执行,3047.94
# 2016-02-26,卖单执行,2942.100000
# 2016-02-29,卖单执行,2939.580000
# 毛收益 -4344.48, 扣佣后收益 -4393.60 , 佣金 49.12
# 2016-03-08,买单执行,3100.15
# 2016-03-16,卖单执行,3068.870000
# 毛收益 -1219.92, 扣佣后收益 -1268.04 , 佣金 48.12
# 2016-03-18,买单执行,3136.22
# 2016-03-31,卖单执行,3229.200000
# 毛收益 3626.22, 扣佣后收益  3576.57 , 佣金 49.65
# 2016-04-07,买单执行,3266.29
# 2016-04-21,卖单执行,3160.800000
# 毛收益 -4008.62, 扣佣后收益 -4057.47 , 佣金 48.85
# 2016-05-04,买单执行,3203.47
# 2016-05-09,卖单执行,3115.430000
# 2016-05-10,卖单执行,3055.210000
# 毛收益 -3405.74, 扣佣后收益 -3453.75 , 佣金 48.01
# 2016-06-02,买单执行,3158.03
# 2016-06-14,卖单执行,3058.440000
# 2016-06-15,卖单执行,3043.960000
# 毛收益 -3699.31, 扣佣后收益 -3745.31 , 佣金 46.00
# 2016-06-24,买单执行,3110.65
# 2016-06-27,卖单执行,3065.130000
# 毛收益 -1638.72, 扣佣后收益 -1683.19 , 佣金 44.47
# 2016-06-29,买单执行,3142.48
# 2016-07-22,卖单执行,3251.240000
# 毛收益 3915.36, 扣佣后收益  3869.33 , 佣金 46.03
# 2016-08-10,买单执行,3255.18
# 2016-08-25,卖单执行,3314.080000
# 2016-08-26,卖单执行,3312.500000
# 毛收益 2118.82, 扣佣后收益  2071.52 , 佣金 47.30
# 2016-09-08,买单执行,3338.01
# 2016-09-13,卖单执行,3265.340000
# 毛收益 -2543.45, 扣佣后收益 -2589.67 , 佣金 46.22
# 2016-10-12,买单执行,3299.14
# 2016-11-03,卖单执行,3326.900000
# 毛收益 971.60, 扣佣后收益  925.22 , 佣金 46.38
# 2016-11-08,买单执行,3367.70
# 2016-12-07,卖单执行,3458.370000
# 2016-12-08,卖单执行,3481.810000
# 毛收益 3196.89, 扣佣后收益  3149.10 , 佣金 47.79
# 2017-01-06,买单执行,3366.85
# 2017-01-13,卖单执行,3317.960000
# 毛收益 -1711.15, 扣佣后收益 -1757.94 , 佣金 46.79
# 2017-01-24,买单执行,3363.14
# 2017-03-03,卖单执行,3424.660000
# 毛收益 2153.20, 扣佣后收益  2105.69 , 佣金 47.51
# 2017-03-15,买单执行,3452.21
# 2017-03-31,卖单执行,3434.820000
# 2017-04-18,卖单执行,3474.890000
# 毛收益 -568.58, 扣佣后收益 -616.80 , 佣金 48.22
# 2017-05-18,买单执行,3387.67
# 2017-06-21,卖单执行,3567.130000
# 毛收益 6281.10, 扣佣后收益  6232.42 , 佣金 48.68
# 2017-06-26,买单执行,3627.02
# 2017-08-11,卖单执行,3687.930000
# 2017-08-14,卖单执行,3651.380000
# 毛收益 2095.30, 扣佣后收益  2044.10 , 佣金 51.20
# 2017-08-23,买单执行,3747.61
# 2017-09-15,卖单执行,3826.140000
# 毛收益 2670.02, 扣佣后收益  2618.52 , 佣金 51.50
# 2017-09-19,买单执行,3849.88
# 2017-09-26,卖单执行,3810.330000
# 毛收益 -1344.70, 扣佣后收益 -1396.79 , 佣金 52.09
# 2017-10-10,买单执行,3883.00
# 2017-11-29,卖单执行,4061.350000
# 毛收益 5885.55, 扣佣后收益  5833.12 , 佣金 52.43
# 2017-12-22,买单执行,4064.91
# 2018-02-01,卖单执行,4276.340000
# 毛收益 6977.19, 扣佣后收益  6922.14 , 佣金 55.05
# 2018-02-28,买单执行,4016.79
# 2018-03-07,卖单执行,4063.500000
# 毛收益 1588.14, 扣佣后收益  1533.19 , 佣金 54.95
# 2018-03-12,买单执行,4130.71
# 2018-03-21,卖单执行,4097.020000
# 毛收益 -1179.15, 扣佣后收益 -1236.74 , 佣金 57.59
# 2018-04-12,买单执行,3935.67
# 2018-04-17,卖单执行,3812.870000
# 2018-04-18,卖单执行,3785.310000
# 毛收益 -4448.36, 扣佣后收益 -4504.14 , 佣金 55.78
# 2018-05-10,买单执行,3882.84
# 2018-05-24,卖单执行,3853.290000
# 毛收益 -1034.25, 扣佣后收益 -1088.40 , 佣金 54.15
# 2018-06-11,买单执行,3770.21
# 2018-06-12,卖单执行,3783.190000
# 毛收益 467.28, 扣佣后收益  412.90 , 佣金 54.38
# 2018-06-13,买单执行,3814.62
# 2018-06-15,卖单执行,3763.040000
# 毛收益 -1856.88, 扣佣后收益 -1911.44 , 佣金 54.56
# 2018-07-16,买单执行,3488.97
# 2018-07-20,卖单执行,3426.460000
# 2018-08-02,卖单执行,3434.350000
# 毛收益 -2430.00, 扣佣后收益 -2483.94 , 佣金 53.94
# 2018-08-16,买单执行,3251.86
# 2018-08-17,卖单执行,3305.900000
# 毛收益 2107.56, 扣佣后收益  2056.41 , 佣金 51.15
# 2018-08-29,买单执行,3393.05
# 2018-09-06,卖单执行,3286.660000
# 毛收益 -4149.21, 扣佣后收益 -4201.31 , 佣金 52.10
# 2018-09-21,买单执行,3320.70
# 2018-10-11,卖单执行,3179.540000
# 毛收益 -5505.24, 扣佣后收益 -5555.94 , 佣金 50.70
# 2018-10-24,买单执行,3169.46
# 2018-11-01,卖单执行,3185.200000
# 毛收益 598.12, 扣佣后收益  549.82 , 佣金 48.30
# 2018-11-05,买单执行,3269.47
# 2018-11-14,卖单执行,3233.640000
# 毛收益 -1361.54, 扣佣后收益 -1410.96 , 佣金 49.42
# 2018-11-19,买单执行,3258.79
# 2018-11-27,卖单执行,3152.770000
# 毛收益 -4028.76, 扣佣后收益 -4077.49 , 佣金 48.73
# 2018-12-04,买单执行,3256.23
# 2018-12-13,卖单执行,3178.890000
# 毛收益 -2861.58, 扣佣后收益 -2909.20 , 佣金 47.62
# 2019-01-08,买单执行,3049.87
# 2019-03-11,卖单执行,3663.980000
# 2019-03-12,卖单执行,3758.320000
# 毛收益 23430.52, 扣佣后收益  23379.48 , 佣金 51.04
# 2019-03-20,买单执行,3825.34
# 2019-03-28,卖单执行,3731.060000
# 毛收益 -3394.08, 扣佣后收益 -3448.49 , 佣金 54.41
# 2019-04-03,买单执行,3947.87
# 2019-04-26,卖单执行,3921.890000
# 毛收益 -883.32, 扣佣后收益 -936.83 , 佣金 53.51
# 2019-06-04,买单执行,3632.56
# 2019-06-06,卖单执行,3601.040000
# 毛收益 -1166.24, 扣佣后收益 -1219.77 , 佣金 53.53
# 2019-06-13,买单执行,3689.58
# 2019-07-11,卖单执行,3806.190000
# 毛收益 4197.96, 扣佣后收益  4143.99 , 佣金 53.97
# 2019-07-29,买单执行,3857.94
# 2019-08-05,卖单执行,3724.410000
# 毛收益 -4807.08, 扣佣后收益 -4861.67 , 佣金 54.59
# 2019-08-19,买单执行,3736.03
# 2019-09-19,卖单执行,3923.960000
# 毛收益 6765.48, 扣佣后收益  6710.33 , 佣金 55.15
# 2019-10-15,买单执行,3953.16
# 2019-10-24,卖单执行,3877.920000
# 毛收益 -2633.40, 扣佣后收益 -2688.22 , 佣金 54.82
# 2019-10-30,买单执行,3904.72
# 2019-11-13,卖单执行,3905.280000
# 毛收益 19.60, 扣佣后收益 -35.07 , 佣金 54.67
# 2019-12-09,买单执行,3909.53
# 2019-12-27,卖单执行,4029.250000
# 毛收益 4190.20, 扣佣后收益  4134.63 , 佣金 55.57
# 2019-12-31,买单执行,4077.75
# 2020-01-23,卖单执行,4093.320000
# 毛收益 544.95, 扣佣后收益  487.75 , 佣金 57.20
# 2020-02-13,买单执行,3985.88
# 2020-03-02,卖单执行,3968.840000
# 2020-03-03,卖单执行,4125.140000
# 毛收益 -457.14, 扣佣后收益 -514.45 , 佣金 57.31
# 2020-04-01,买单执行,3682.30
# 2020-05-20,卖单执行,3955.710000
# 毛收益 10389.58, 扣佣后收益  10331.53 , 佣金 58.05
# 2020-06-03,买单执行,4001.17
# 2020-06-19,卖单执行,4047.050000
# 毛收益 1743.44, 扣佣后收益  1682.27 , 佣金 61.17
# 2020-06-23,买单执行,4098.04
# 2020-07-17,卖单执行,4524.770000
# 2020-07-20,卖单执行,4597.200000
# 毛收益 15861.44, 扣佣后收益  15797.62 , 佣金 63.82
# 2020-08-05,买单执行,4761.76
# 2020-08-13,卖单执行,4666.490000
# 毛收益 -3334.45, 扣佣后收益 -3400.45 , 佣金 66.00
# 2020-08-20,买单执行,4708.13
# 2020-08-27,卖单执行,4718.060000
# 毛收益 337.62, 扣佣后收益  273.52 , 佣金 64.10
# 2020-09-01,买单执行,4803.39
# 2020-09-09,卖单执行,4634.250000
# 毛收益 -5750.76, 扣佣后收益 -5814.94 , 佣金 64.18
# 2020-09-21,买单执行,4750.75
# 2020-09-25,卖单执行,4582.480000
# 2020-09-28,卖单执行,4582.650000
# 毛收益 -5721.01, 扣佣后收益 -5784.48 , 佣金 63.47
# 2020-10-14,买单执行,4830.46
# 2020-10-23,卖单执行,4775.470000
# 毛收益 -1759.68, 扣佣后收益 -1821.16 , 佣金 61.48
# 2020-11-04,买单执行,4781.45
# 2020-11-19,卖单执行,4880.920000
# 毛收益 3183.04, 扣佣后收益  3121.20 , 佣金 61.84
# 2020-11-24,买单执行,4997.05
# 2020-12-11,卖单执行,4957.820000
# 毛收益 -1216.13, 扣佣后收益 -1277.85 , 佣金 61.72
# 2020-12-22,买单执行,5034.98
# 2021-01-22,卖单执行,5562.380000
# 毛收益 16349.40, 扣佣后收益  16283.70 , 佣金 65.70
# 2021-01-27,买单执行,5505.77
# 2021-02-01,卖单执行,5356.850000
# 毛收益 -4467.60, 扣佣后收益 -4532.78 , 佣金 65.18
# 2021-02-09,买单执行,5584.17
# 2021-02-24,卖单执行,5591.480000
# 毛收益 219.30, 扣佣后收益  152.25 , 佣金 67.05
# 2021-03-19,买单执行,5068.53
# 2021-03-23,卖单执行,5057.060000
# 毛收益 -367.04, 扣佣后收益 -431.84 , 佣金 64.80
# 2021-04-06,买单执行,5178.64
# 2021-04-12,卖单执行,5026.980000
# 毛收益 -4853.12, 扣佣后收益 -4918.44 , 佣金 65.32
# 2021-04-23,买单执行,5088.83
# 2021-05-10,卖单执行,5001.440000
# 毛收益 -2709.09, 扣佣后收益 -2771.65 , 佣金 62.56
# 2021-05-19,买单执行,5173.17
# 2021-06-04,卖单执行,5228.280000
# 毛收益 1653.30, 扣佣后收益  1590.89 , 佣金 62.41
# 2021-06-29,买单执行,5248.52
# 2021-07-06,卖单执行,5089.780000
# 毛收益 -4762.20, 扣佣后收益 -4824.23 , 佣金 62.03
# 2021-07-14,买单执行,5130.75
# 2021-07-27,卖单执行,4924.280000
# 2021-07-28,卖单执行,4714.290000
# 毛收益 -6404.09, 扣佣后收益 -6464.38 , 佣金 60.29
# 2021-08-06,买单执行,4943.04
# 2021-08-18,卖单执行,4838.470000
# 2021-08-19,卖单执行,4886.560000
# 毛收益 -3089.01, 扣佣后收益 -3147.71 , 佣金 58.70
# 2021-09-02,买单执行,4865.82
# 2021-09-17,卖单执行,4797.110000
# 2021-09-22,卖单执行,4770.730000
# 毛收益 -2087.68, 扣佣后收益 -2145.65 , 佣金 57.97
# 2021-10-11,买单执行,4941.29
# 2021-10-29,卖单执行,4861.270000
# 毛收益 -2320.58, 扣佣后收益 -2377.43 , 佣金 56.85
# 2021-11-15,买单执行,4894.41
# 2021-12-01,卖单执行,4831.890000
# 毛收益 -1813.08, 扣佣后收益 -1869.49 , 佣金 56.41
# 2021-12-08,买单执行,4934.41
# 2021-12-21,卖单执行,4876.510000
# 毛收益 -1621.20, 扣佣后收益 -1676.14 , 佣金 54.94
# end portfolio value: 139370.34120600007

# %%
#画图仍只能在notebook中输出(将basic改成full的话可以得到更多的输出结果，但其中一个return distribution的表会报错)
qs.reports.basic(returns,rf=0.0,grayscale=False,display=True,compounded = True)
#只有在full中有和benchmark的对比
qs.reports.full(returns,benchmark=stock_df['close'],rf=0.0,grayscale=False,display=True,compounded = True)
# Out:
# <h4>Performance Metrics</h4>
#                     Strategy
# ------------------  ----------
# Start Period        2014-03-07
# End Period          2021-12-30
# Risk-Free Rate      0.0%
# Time in Market      60.0%
#
# Cumulative Return   39.37%
# CAGR﹪              4.34%
#
# Sharpe              0.39
# Sortino             0.55
# Sortino/√2          0.39
# Omega               1.1
#
# Max Drawdown        -31.18%
# Longest DD Days     1864
#
# Gain/Pain Ratio     0.1
# Gain/Pain (1M)      0.34
#
# Payoff Ratio        1.07
# Profit Factor       1.1
# Common Sense Ratio  1.26
# CPC Index           0.6
# Tail Ratio          1.15
# Outlier Win Ratio   8.39
# Outlier Loss Ratio  3.93
#
# MTD                 -1.21%
# 3M                  -4.08%
# 6M                  -12.95%
# YTD                 -13.94%
# 1Y                  -11.07%
# 3Y (ann.)           5.64%
# 5Y (ann.)           2.86%
# 10Y (ann.)          4.34%
# All-time (ann.)     4.34%
#
# Avg. Drawdown       -5.1%
# Avg. Drawdown Days  139
# Recovery Factor     1.26
# Ulcer Index         0.18
# Serenity Index      0.07
# <h4>Strategy Visualization</h4>
# <h4>Performance Metrics</h4>
#                            Strategy    Benchmark
# -------------------------  ----------  -----------
# Start Period               2014-03-07  2014-03-07
# End Period                 2021-12-30  2021-12-30
# Risk-Free Rate             0.0%        0.0%
# Time in Market             60.0%       100.0%
#
# Cumulative Return          39.37%      126.97%
# CAGR﹪                     4.34%       11.05%
#
# Sharpe                     0.39        0.58
# Smart Sharpe               0.37        0.56
# Sortino                    0.55        0.8
# Smart Sortino              0.52        0.76
# Sortino/√2                 0.39        0.57
# Smart Sortino/√2           0.37        0.54
# Omega                      1.1         1.1
#
# Max Drawdown               -31.18%     -46.7%
# Longest DD Days            1864        2037
# Volatility (ann.)          13.85%      23.13%
# R^2                        0.37        0.37
# Calmar                     0.14        0.24
# Skew                       -0.43       -0.75
# Kurtosis                   11.28       5.68
#
# Expected Daily %           0.02%       0.04%
# Expected Monthly %         0.35%       0.88%
# Expected Yearly %          4.24%       10.79%
# Kelly Criterion            4.08%       8.24%
# Risk of Ruin               0.0%        0.0%
# Daily Value-at-Risk        -1.41%      -2.34%
# Expected Shortfall (cVaR)  -1.41%      -2.34%
#
# Gain/Pain Ratio            0.1         0.12
# Gain/Pain (1M)             0.34        0.66
#
# Payoff Ratio               1.05        1.04
# Profit Factor              1.1         1.12
# Common Sense Ratio         1.26        1.21
# CPC Index                  0.59        0.62
# Tail Ratio                 1.15        1.08
# Outlier Win Ratio          9.75        3.34
# Outlier Loss Ratio         5.29        3.86
#
# MTD                        -1.21%      1.85%
# 3M                         -4.08%      0.77%
# 6M                         -12.95%     -5.18%
# YTD                        -13.94%     -5.56%
# 1Y                         -11.07%     -2.41%
# 3Y (ann.)                  5.64%       17.84%
# 5Y (ann.)                  2.86%       8.27%
# 10Y (ann.)                 4.34%       11.05%
# All-time (ann.)            4.34%       11.05%
#
# Best Day                   5.85%       6.71%
# Worst Day                  -6.54%      -8.75%
# Best Month                 23.02%      25.81%
# Worst Month                -8.59%      -21.04%
# Best Year                  25.78%      62.97%
# Worst Year                 -13.94%     -25.31%
#
# Avg. Drawdown              -5.1%       -4.53%
# Avg. Drawdown Days         139         88
# Recovery Factor            1.26        2.72
# Ulcer Index                0.18        0.27
# Serenity Index             0.07        0.15
#
# Avg. Up Month              4.55%       6.53%
# Avg. Down Month            -3.09%      -4.17%
# Win Days %                 50.79%      53.33%
# Win Month %                46.74%      60.64%
# Win Quarter %              53.12%      59.38%
# Win Year %                 62.5%       62.5%
# Beta                       0.37        -
# Alpha                      0.0         -
# None
# <h4>5 Worst Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2015-05-27  2016-06-27  2020-07-03  1864    -31.180053        -30.141160
# 2  2020-07-14  2021-12-21  2021-12-30   534    -23.970757        -23.896136
# 3  2015-01-08  2015-03-06  2015-03-23    74     -7.834794         -7.829318
# 4  2014-04-03  2014-07-11  2014-07-28   116     -6.626920         -6.556401
# 5  2014-08-05  2014-09-16  2014-12-02   119     -6.341106         -6.102070
# <h4>Strategy Visualization</h4>
