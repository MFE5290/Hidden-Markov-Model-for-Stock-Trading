# %%
import pandas as pd
import datetime as dt
import backtrader as bt
import quantstats as qs
import matplotlib as plt
import numpy as np
import os

os.getcwd()

# 数据加载-------------------------------------
df = pd.read_csv("test_set.csv")  # 绝对路径
df.index = pd.to_datetime(df.date)
df['openinterest'] = 0

# #以下是自己随机添加signal的之后的文件，hmm算法给出的带signal的文件直接用上面的df=pd.read_csv导入，把下面到构建策略之前mute掉即可

# #随机生成一个-1，0，1的predictions序列---------
# sig=[]
# for i in range(len(df)):
#     x=np.random.randn()
#     if x > 0.2:
#         sig.append(1)
#     elif x<-0.2:
#         sig.append(-1)
#     else:
#         sig.append(0)
# df['signal']=sig


# 构建策略-------------------------------------
class TestSignalStrategy(bt.Strategy):
    params = ()

    def log(self, txt, dt=None):
        dt = dt or self.datas[0].datetime.date(0)
        print('%s,%s' % (dt.isoformat(), txt))

    def __init__(self):
        self.bar_num = 0
        self.signal_df = df
        self.signal_df['date'] = pd.to_datetime(self.signal_df['date'])
        self.first_trade = True

    def prenext(self):
        self.next()

    def next(self):
        self.bar_num += 1
        current_date = self.datas[0].datetime.date(0).strftime("%Y-%m-%d")
        try:
            next_date = self.datas[0].datetime.date(1)
        except:
            next_date = None
        if next_date != None:
            next_signal_df = self.signal_df[self.signal_df['date'] == pd.to_datetime(
                next_date)]
            if len(next_signal_df) == 0:
                self.log("下个交易日的信号不存在")
            else:
                signal = int(next_signal_df['signal'])

                # 第一次交易没有底仓，只允许做多
                # 交易信号的执行方式：
                # 先不考虑卖空
                # signal为1，以当天开盘价全仓买入
                # signal为-1时，以当天开盘价卖出所有持仓
                if self.first_trade:
                    if signal == -1:
                        pass
                    if signal == 1:
                        total_value = self.broker.get_value()
                        open_price = self.datas[0].open[0]
                        target_size = total_value//open_price
                        self.buy(self.datas[0],
                                 size=target_size, price=open_price)
                        self.first_trade = False
                else:
                    # 现有持仓
                    now_hold_size = self.getposition(self.datas[0]).size
                    if signal == 1:
                        total_value = self.broker.get_value()
                        open_price = self.datas[0].open[0]
                        target_size = total_value//open_price
                        self.buy(self.datas[0],
                                 size=target_size, price=open_price)

                    if signal == -1:
                        total_value = self.broker.get_value()
                        open_price = self.datas[0].open[0]
                        target_size = total_value//open_price
                        # 卖出开仓，手数不能超过底仓
                        if target_size > now_hold_size:
                            target_size = now_hold_size

                        self.sell(
                            self.datas[0], size=target_size, price=open_price)

    # 订单情况
    def notify_order(self, order):

        # 订单处于未决，继续
        if order.status in [order.Submitted, order.Accepted]:
            return

        # 订单已决
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log('买单执行,%.2f' % order.executed.price)

            elif order.issell():
                self.log('卖单执行,%2f' % order.executed.price)

        elif order.status in [order.Canceled, order.Rejected, order.Expired]:
            self.log('订单 Canceled/Rejected/Expired')

    # 交易情况
    def notify_trade(self, trade):
        if trade.isclosed:
            print('毛收益 %0.2f, 扣佣后收益 % 0.2f , 佣金 %.2f'
                  % (trade.pnl, trade.pnlcomm, trade.commission))


cerebro = bt.Cerebro()

stock_df = df[['open', 'high', 'low', 'close', 'volume', 'openinterest']]
data = bt.feeds.PandasData(dataname=stock_df, fromdate=dt.datetime(
    2010, 1, 4), todate=dt.datetime(2021, 12, 31), timeframe=bt.TimeFrame.Days)
cerebro.adddata(data)

# 初始资金设置为10万
cerebro.broker.setcash(100000.0)
# 手续费万分之二
cerebro.broker.setcommission(commission=0.0002)
# 滑点设置 0.5%
cerebro.broker = bt.brokers.BackBroker(slip_perc=0.005)

cerebro.addstrategy(TestSignalStrategy)
cerebro.addanalyzer(bt.analyzers.PyFolio, _name='PyFolio')

# 运行回测
print('start portfolio value:', format(cerebro.broker.getvalue()))
results = cerebro.run()
print('end portfolio value:', format(cerebro.broker.getvalue()))


# 绩效评价----------------------------
# 获取策略实例
start = results[0]
portfolio_stats = start.analyzers.getbyname('PyFolio')
# 以下returns为以日期为索引的资产日收益率序列
returns, positions, transactions, gross_lev = portfolio_stats.get_pf_items()
returns.index = returns.index.tz_convert(None)
# Out:
# start portfolio value: 10000.0
# 2013-08-08,买单执行,2277.25
# 2013-08-16,卖单执行,2314.260000
# 毛收益 148.04, 扣佣后收益  148.04 , 佣金 0.00
# 2013-09-04,买单执行,2352.54
# 2013-09-05,卖单执行,2350.930000
# 毛收益 -6.44, 扣佣后收益 -6.44 , 佣金 0.00
# 2013-09-10,买单执行,2446.45
# 2013-09-18,卖单执行,2426.040000
# 毛收益 -81.64, 扣佣后收益 -81.64 , 佣金 0.00
# 2013-10-15,买单执行,2475.32
# 2013-10-17,卖单执行,2432.640000
# 毛收益 -170.72, 扣佣后收益 -170.72 , 佣金 0.00
# 2013-12-06,买单执行,2463.04
# 2013-12-10,卖单执行,2456.230000
# 毛收益 -20.43, 扣佣后收益 -20.43 , 佣金 0.00
# 2014-02-13,买单执行,2288.45
# 2014-02-21,卖单执行,2284.030000
# 毛收益 -17.68, 扣佣后收益 -17.68 , 佣金 0.00
# 2014-04-09,买单执行,2239.79
# 2014-04-17,卖单执行,2238.780000
# 毛收益 -4.04, 扣佣后收益 -4.04 , 佣金 0.00
# 2014-05-29,买单执行,2171.26
# 2014-06-05,卖单执行,2126.610000
# 毛收益 -178.60, 扣佣后收益 -178.60 , 佣金 0.00
# 2014-06-16,买单执行,2176.44
# 2014-06-20,卖单执行,2124.960000
# 毛收益 -205.92, 扣佣后收益 -205.92 , 佣金 0.00
# 2014-07-01,买单执行,2169.20
# 2014-07-10,卖单执行,2146.600000
# 毛收益 -90.40, 扣佣后收益 -90.40 , 佣金 0.00
# 2014-07-23,买单执行,2191.39
# 2014-08-08,卖单执行,2329.180000
# 毛收益 551.16, 扣佣后收益  551.16 , 佣金 0.00
# 2014-09-04,买单执行,2411.93
# 2014-09-17,卖单执行,2395.360000
# 毛收益 -66.28, 扣佣后收益 -66.28 , 佣金 0.00
# 2014-10-10,买单执行,2472.10
# 2014-10-15,卖单执行,2444.540000
# 毛收益 -82.68, 扣佣后收益 -82.68 , 佣金 0.00
# 2014-11-04,买单执行,2511.04
# 2014-11-19,卖单执行,2538.230000
# 毛收益 81.57, 扣佣后收益  81.57 , 佣金 0.00
# 2014-11-27,买单执行,2737.03
# 2014-12-15,卖单执行,3176.830000
# 毛收益 1319.40, 扣佣后收益  1319.40 , 佣金 0.00
# 2014-12-19,买单执行,3345.63
# 2014-12-25,卖单执行,3254.480000
# 毛收益 -273.45, 扣佣后收益 -273.45 , 佣金 0.00
# 2015-01-06,买单执行,3608.43
# 2015-01-12,卖单执行,3531.510000
# 毛收益 -230.76, 扣佣后收益 -230.76 , 佣金 0.00
# 2015-02-17,买单执行,3511.54
# 2015-03-04,卖单执行,3514.670000
# 2015-03-05,卖单执行,3513.250000
# 毛收益 7.97, 扣佣后收益  7.97 , 佣金 0.00
# 2015-03-17,买单执行,3733.96
# 2015-05-05,卖单执行,4785.190000
# 毛收益 2102.46, 扣佣后收益  2102.46 , 佣金 0.00
# 2015-05-27,买单执行,5216.17
# 2015-05-29,卖单执行,4839.530000
# 毛收益 -753.28, 扣佣后收益 -753.28 , 佣金 0.00
# 2015-06-09,买单执行,5379.47
# 2015-06-16,卖单执行,5165.020000
# 毛收益 -428.90, 扣佣后收益 -428.90 , 佣金 0.00
# 2015-08-18,买单执行,4084.31
# 2015-08-19,卖单执行,3748.270000
# 毛收益 -672.08, 扣佣后收益 -672.08 , 佣金 0.00
# 2015-10-14,买单执行,3431.14
# 2015-10-22,卖单执行,3453.200000
# 毛收益 66.18, 扣佣后收益  66.18 , 佣金 0.00
# 2015-11-10,买单执行,3806.67
# 2015-11-17,卖单执行,3790.430000
# 毛收益 -32.48, 扣佣后收益 -32.48 , 佣金 0.00
# 2015-12-21,买单执行,3762.10
# 2015-12-29,卖单执行,3723.050000
# 毛收益 -78.10, 扣佣后收益 -78.10 , 佣金 0.00
# 2016-02-18,买单执行,3079.53
# 2016-02-26,卖单执行,2942.100000
# 毛收益 -412.29, 扣佣后收益 -412.29 , 佣金 0.00
# 2016-03-08,买单执行,3100.15
# 2016-03-11,卖单执行,2990.210000
# 毛收益 -329.82, 扣佣后收益 -329.82 , 佣金 0.00
# 2016-03-22,买单执行,3231.61
# 2016-03-29,卖单执行,3171.310000
# 毛收益 -180.90, 扣佣后收益 -180.90 , 佣金 0.00
# 2016-06-06,买单执行,3192.78
# 2016-06-14,卖单执行,3058.440000
# 毛收益 -403.02, 扣佣后收益 -403.02 , 佣金 0.00
# 2016-06-23,买单执行,3129.72
# 2016-06-27,卖单执行,3065.130000
# 毛收益 -193.77, 扣佣后收益 -193.77 , 佣金 0.00
# 2016-07-06,买单执行,3197.62
# 2016-07-21,卖单执行,3238.340000
# 毛收益 81.44, 扣佣后收益  81.44 , 佣金 0.00
# 2016-08-10,买单执行,3255.18
# 2016-08-24,卖单执行,3341.930000
# 毛收益 173.50, 扣佣后收益  173.50 , 佣金 0.00
# 2016-10-13,买单执行,3299.16
# 2016-10-21,卖单执行,3315.720000
# 毛收益 33.12, 扣佣后收益  33.12 , 佣金 0.00
# 2016-10-26,买单执行,3365.20
# 2016-10-31,卖单执行,3332.410000
# 毛收益 -65.58, 扣佣后收益 -65.58 , 佣金 0.00
# 2016-11-14,买单执行,3409.22
# 2016-12-06,卖单执行,3466.240000
# 毛收益 114.04, 扣佣后收益  114.04 , 佣金 0.00
# 2017-01-05,买单执行,3368.34
# 2017-01-13,卖单执行,3317.960000
# 毛收益 -100.76, 扣佣后收益 -100.76 , 佣金 0.00
# 2017-01-24,买单执行,3363.14
# 2017-02-08,卖单执行,3361.780000
# 毛收益 -2.72, 扣佣后收益 -2.72 , 佣金 0.00
# 2017-02-13,买单执行,3416.92
# 2017-02-28,卖单执行,3445.030000
# 毛收益 56.22, 扣佣后收益  56.22 , 佣金 0.00
# 2017-04-13,买单执行,3500.28
# 2017-04-17,卖单执行,3475.740000
# 毛收益 -49.08, 扣佣后收益 -49.08 , 佣金 0.00
# 2017-05-19,买单执行,3395.23
# 2017-06-19,卖单执行,3520.060000
# 毛收益 249.66, 扣佣后收益  249.66 , 佣金 0.00
# 2017-06-26,买单执行,3627.02
# 2017-07-05,卖单执行,3611.900000
# 毛收益 -30.24, 扣佣后收益 -30.24 , 佣金 0.00
# 2017-07-14,买单执行,3682.62
# 2017-07-18,卖单执行,3648.490000
# 毛收益 -68.26, 扣佣后收益 -68.26 , 佣金 0.00
# 2017-08-23,买单执行,3747.61
# 2017-09-07,卖单执行,3851.690000
# 毛收益 208.16, 扣佣后收益  208.16 , 佣金 0.00
# 2017-10-11,买单执行,3886.82
# 2017-10-24,卖单执行,3926.230000
# 毛收益 78.82, 扣佣后收益  78.82 , 佣金 0.00
# 2017-10-26,买单执行,3980.05
# 2017-11-07,卖单执行,4022.400000
# 毛收益 84.70, 扣佣后收益  84.70 , 佣金 0.00
# 2017-11-10,买单执行,4070.28
# 2017-11-24,卖单执行,4089.470000
# 毛收益 38.38, 扣佣后收益  38.38 , 佣金 0.00
# 2017-12-27,买单执行,4045.28
# 2017-12-28,卖单执行,3993.000000
# 毛收益 -104.56, 扣佣后收益 -104.56 , 佣金 0.00
# 2018-01-09,买单执行,4157.54
# 2018-01-30,卖单执行,4286.680000
# 毛收益 258.28, 扣佣后收益  258.28 , 佣金 0.00
# 2018-02-28,买单执行,4016.79
# 2018-03-05,卖单执行,4021.660000
# 毛收益 9.74, 扣佣后收益  9.74 , 佣金 0.00
# 2018-03-14,买单执行,4076.06
# 2018-03-15,卖单执行,4058.710000
# 毛收益 -34.70, 扣佣后收益 -34.70 , 佣金 0.00
# 2018-05-10,买单执行,3882.84
# 2018-05-18,卖单执行,3860.160000
# 毛收益 -45.36, 扣佣后收益 -45.36 , 佣金 0.00
# 2018-07-27,买单执行,3533.77
# 2018-08-01,卖单执行,3530.030000
# 毛收益 -7.48, 扣佣后收益 -7.48 , 佣金 0.00
# 2018-08-29,买单执行,3393.05
# 2018-08-31,卖单执行,3333.380000
# 2018-09-03,卖单执行,3320.690000
# 毛收益 -191.70, 扣佣后收益 -191.70 , 佣金 0.00
# 2018-09-26,买单执行,3388.56
# 2018-10-09,卖单执行,3290.170000
# 毛收益 -196.78, 扣佣后收益 -196.78 , 佣金 0.00
# 2018-12-06,买单执行,3218.11
# 2018-12-07,卖单执行,3187.490000
# 毛收益 -91.86, 扣佣后收益 -91.86 , 佣金 0.00
# 2019-01-14,买单执行,3092.50
# 2019-01-25,卖单执行,3165.180000
# 毛收益 218.04, 扣佣后收益  218.04 , 佣金 0.00
# 2019-02-01,买单执行,3225.73
# 2019-03-01,卖单执行,3699.220000
# 毛收益 1420.47, 扣佣后收益  1420.47 , 佣金 0.00
# 2019-03-04,买单执行,3783.04
# 2019-03-11,卖单执行,3663.980000
# 2019-03-12,卖单执行,3758.320000
# 毛收益 -262.84, 扣佣后收益 -262.84 , 佣金 0.00
# 2019-04-04,买单执行,4039.74
# 2019-04-12,卖单执行,3986.780000
# 毛收益 -105.92, 扣佣后收益 -105.92 , 佣金 0.00
# 2019-06-25,买单执行,3837.43
# 2019-07-02,卖单执行,3931.050000
# 毛收益 187.24, 扣佣后收益  187.24 , 佣金 0.00
# 2019-07-30,买单执行,3861.57
# 2019-08-02,卖单执行,3729.130000
# 毛收益 -264.88, 扣佣后收益 -264.88 , 佣金 0.00
# 2019-08-20,买单执行,3786.03
# 2019-08-29,卖单执行,3805.490000
# 毛收益 38.92, 扣佣后收益  38.92 , 佣金 0.00
# 2019-09-05,买单执行,3909.21
# 2019-09-18,卖单执行,3902.990000
# 毛收益 -12.44, 扣佣后收益 -12.44 , 佣金 0.00
# 2019-10-15,买单执行,3953.16
# 2019-10-21,卖单执行,3865.340000
# 毛收益 -175.64, 扣佣后收益 -175.64 , 佣金 0.00
# 2019-11-05,买单执行,3982.12
# 2019-11-12,卖单执行,3905.960000
# 毛收益 -152.32, 扣佣后收益 -152.32 , 佣金 0.00
# 2019-12-11,买单执行,3907.16
# 2019-12-25,卖单执行,3988.660000
# 毛收益 163.00, 扣佣后收益  163.00 , 佣金 0.00
# 2020-01-03,买单执行,4161.22
# 2020-01-14,卖单执行,4215.160000
# 毛收益 107.88, 扣佣后收益  107.88 , 佣金 0.00
# 2020-02-13,买单执行,3985.88
# 2020-02-27,卖单执行,4084.080000
# 毛收益 196.40, 扣佣后收益  196.40 , 佣金 0.00
# 2020-05-06,买单执行,3867.26
# 2020-05-15,卖单执行,3941.130000
# 毛收益 147.74, 扣佣后收益  147.74 , 佣金 0.00
# 2020-06-03,买单执行,4001.17
# 2020-06-12,卖单执行,3931.620000
# 毛收益 -139.10, 扣佣后收益 -139.10 , 佣金 0.00
# 2020-06-24,买单执行,4128.10
# 2020-07-16,卖单执行,4741.530000
# 毛收益 1226.86, 扣佣后收益  1226.86 , 佣金 0.00
# 2020-08-05,买单执行,4761.76
# 2020-08-10,卖单执行,4681.760000
# 毛收益 -160.00, 扣佣后收益 -160.00 , 佣金 0.00
# 2020-09-21,买单执行,4750.75
# 2020-09-23,卖单执行,4639.660000
# 毛收益 -222.18, 扣佣后收益 -222.18 , 佣金 0.00
# 2020-10-14,买单执行,4830.46
# 2020-10-22,卖单执行,4780.600000
# 毛收益 -99.72, 扣佣后收益 -99.72 , 佣金 0.00
# 2020-11-06,买单执行,4897.63
# 2020-11-16,卖单执行,4880.960000
# 毛收益 -33.34, 扣佣后收益 -33.34 , 佣金 0.00
# 2020-11-25,买单执行,4992.75
# 2020-11-26,卖单执行,4908.320000
# 毛收益 -168.86, 扣佣后收益 -168.86 , 佣金 0.00
# 2020-12-07,买单执行,5065.73
# 2020-12-09,卖单执行,5022.380000
# 毛收益 -86.70, 扣佣后收益 -86.70 , 佣金 0.00
# 2021-01-04,买单执行,5212.93
# 2021-01-18,卖单执行,5438.160000
# 毛收益 450.46, 扣佣后收益  450.46 , 佣金 0.00
# 2021-02-09,买单执行,5584.17
# 2021-02-23,卖单执行,5542.680000
# 毛收益 -82.98, 扣佣后收益 -82.98 , 佣金 0.00
# 2021-04-06,买单执行,5178.64
# 2021-04-09,卖单执行,5100.040000
# 毛收益 -157.20, 扣佣后收益 -157.20 , 佣金 0.00
# 2021-04-23,买单执行,5088.83
# 2021-04-29,卖单执行,5128.280000
# 毛收益 78.90, 扣佣后收益  78.90 , 佣金 0.00
# 2021-04-30,买单执行,5156.36
# 2021-05-06,卖单执行,5098.800000
# 毛收益 -115.12, 扣佣后收益 -115.12 , 佣金 0.00
# 2021-05-20,买单执行,5167.05
# 2021-06-04,卖单执行,5228.280000
# 毛收益 122.46, 扣佣后收益  122.46 , 佣金 0.00
# 2021-06-28,买单执行,5253.61
# 2021-07-05,卖单执行,5073.780000
# 毛收益 -359.66, 扣佣后收益 -359.66 , 佣金 0.00
# 2021-08-06,买单执行,4943.04
# 2021-08-13,卖单执行,4958.760000
# 毛收益 31.44, 扣佣后收益  31.44 , 佣金 0.00
# 2021-09-07,买单执行,4932.98
# 2021-09-16,卖单执行,4866.790000
# 毛收益 -132.38, 扣佣后收益 -132.38 , 佣金 0.00
# 2021-12-09,买单执行,5000.69
# 2021-12-20,卖单执行,4934.970000
# 毛收益 -131.44, 扣佣后收益 -131.44 , 佣金 0.00
# end portfolio value: 11287.170000000007

# %%
# 画图仍只能在notebook中输出(将basic改成full的话可以得到更多的输出结果，但其中一个return distribution的表会报错)
qs.reports.basic(returns, benchmark=None, rf=0.0,
                 grayscale=False, display=True, compounded=True)
# Out:
# <h4>Performance Metrics</h4>
#                     Strategy
# ------------------  ----------
# Start Period        2010-01-04
# End Period          2021-12-30
# Risk-Free Rate      0.0%
# Time in Market      34.0%
#
# Cumulative Return   -4.95%
# CAGR﹪              -0.42%
#
# Sharpe              -0.0
# Sortino             -0.01
# Sortino/√2          -0.0
# Omega               1.0
#
# Max Drawdown        -27.98%
# Longest DD Days     2438
#
# Gain/Pain Ratio     -0.0
# Gain/Pain (1M)      -0.0
#
# Payoff Ratio        1.08
# Profit Factor       1.0
# Common Sense Ratio  0.97
# CPC Index           0.52
# Tail Ratio          0.98
# Outlier Win Ratio   14.9
# Outlier Loss Ratio  2.83
#
# MTD                 -0.3%
# 3M                  -2.25%
# 6M                  -3.52%
# YTD                 -6.37%
# 1Y                  -6.37%
# 3Y (ann.)           -1.78%
# 5Y (ann.)           0.03%
# 10Y (ann.)          -0.72%
# All-time (ann.)     -0.42%
#
# Avg. Drawdown       -5.62%
# Avg. Drawdown Days  335
# Recovery Factor     -0.18
# Ulcer Index         0.17
# Serenity Index      -0.01
# <h4>Strategy Visualization</h4>

# %%
# 画图仍只能在notebook中输出
qs.reports.full(returns, benchmark=None, rf=0.0,
                grayscale=False, display=True, compounded=True)
# Out:
# <h4>Performance Metrics</h4>
#                            Strategy
# -------------------------  ----------
# Start Period               2013-07-17
# End Period                 2021-12-30
# Risk-Free Rate             0.0%
# Time in Market             32.0%
#
# Cumulative Return          12.87%
# CAGR﹪                     1.44%
#
# Sharpe                     0.21
# Smart Sharpe               0.21
# Sortino                    0.31
# Smart Sortino              0.3
# Sortino/√2                 0.22
# Smart Sortino/√2           0.21
# Omega                      1.08
#
# Max Drawdown               -27.08%
# Longest DD Days            2438
# Volatility (ann.)          8.9%
# Calmar                     0.05
# Skew                       -0.08
# Kurtosis                   26.55
#
# Expected Daily %           0.01%
# Expected Monthly %         0.12%
# Expected Yearly %          1.35%
# Kelly Criterion            3.38%
# Risk of Ruin               0.0%
# Daily Value-at-Risk        -0.91%
# Expected Shortfall (cVaR)  -0.91%
#
# Gain/Pain Ratio            0.08
# Gain/Pain (1M)             0.2
#
# Payoff Ratio               1.17
# Profit Factor              1.08
# Common Sense Ratio         1.18
# CPC Index                  0.6
# Tail Ratio                 1.09
# Outlier Win Ratio          15.39
# Outlier Loss Ratio         2.93
#
# MTD                        -1.15%
# 3M                         -1.15%
# 6M                         -3.96%
# YTD                        -2.55%
# 1Y                         -2.55%
# 3Y (ann.)                  4.97%
# 5Y (ann.)                  3.08%
# 10Y (ann.)                 1.44%
# All-time (ann.)            1.44%
#
# Best Day                   5.78%
# Worst Day                  -5.47%
# Best Month                 13.34%
# Worst Month                -5.99%
# Best Year                  10.8%
# Worst Year                 -10.87%
#
# Avg. Drawdown              -5.48%
# Avg. Drawdown Days         337
# Recovery Factor            0.48
# Ulcer Index                0.16
# Serenity Index             0.02
#
# Avg. Up Month              2.92%
# Avg. Down Month            -1.54%
# Win Days %                 47.98%
# Win Month %                39.02%
# Win Quarter %              47.06%
# Win Year %                 44.44%
# None
# <h4>5 Worst Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2015-04-28  2016-07-08  2021-12-30  2438    -27.084379        -26.211957
# 2  2013-09-13  2014-07-10  2014-12-02   445     -9.758030         -9.676764
# 3  2014-12-09  2015-02-25  2015-04-01   113     -7.285401         -6.518005
# 4  2013-08-14  2013-09-04  2013-09-12    29     -1.806865         -1.797956
# 5  2015-04-20  2015-04-20  2015-04-21     1     -1.196763          0.000000
# <h4>Strategy Visualization</h4>
