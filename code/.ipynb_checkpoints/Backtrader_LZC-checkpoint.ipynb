# %%
import pandas as pd
import datetime as dt
import backtrader as bt
import quantstats as qs
import matplotlib as plt
import numpy as np
import os

os.getcwd()

#数据加载-------------------------------------
df=pd.read_csv("test_set.csv")#绝对路径
df.index=pd.to_datetime(df.date)
df['openinterest']=0

# #以下是自己随机添加signal的之后的文件，hmm算法给出的带signal的文件直接用上面的df=pd.read_csv导入，把下面到构建策略之前mute掉即可

# #随机生成一个-1，0，1的predictions序列---------
# sig=[]
# for i in range(len(df)):
#     x=np.random.randn()
#     if x > 0.2:
#         sig.append(1)
#     elif x<-0.2:
#         sig.append(-1)
#     else:
#         sig.append(0)
# df['signal']=sig



#构建策略-------------------------------------
class TestSignalStrategy(bt.Strategy):
    params=()

    def log(self,txt,dt=None):
        dt= dt or self.datas[0].datetime.date(0)
        print('%s,%s' % (dt.isoformat(),txt)) 

    def __init__(self):
        self.bar_num=0
        self.signal_df=df
        self.signal_df['date']=pd.to_datetime(self.signal_df['date'])
        self.first_trade=True

    def prenext(self):
        self.next()

    def next(self):
        self.bar_num+=1
        current_date=self.datas[0].datetime.date(0).strftime("%Y-%m-%d")
        try:
            next_date =self.datas[0].datetime.date(1)
        except:
            next_date=None
        if next_date != None:
            next_signal_df= self.signal_df[self.signal_df['date']==pd.to_datetime(next_date)]
            if len(next_signal_df)==0:
                self.log("下个交易日的信号不存在")
            else:
                signal = int(next_signal_df['signal'])
                
                #第一次交易没有底仓，只允许做多
                #交易信号的执行方式：
                #先不考虑卖空
                #signal为1，以当天开盘价全仓买入
                #signal为-1时，以当天开盘价卖出所有持仓
                if self.first_trade:
                    if signal==-1:
                        pass
                    if signal == 1:
                        total_value = self.broker.get_value()
                        open_price = self.datas[0].open[0]
                        target_size=total_value//open_price
                        self.buy(self.datas[0],size=target_size,price=open_price)
                        self.first_trade=False
                else:
                    #现有持仓
                    now_hold_size = self.getposition(self.datas[0]).size
                    if signal == 1:
                        total_value = self.broker.get_value()
                        open_price = self.datas[0].open[0]
                        target_size=total_value//open_price
                        self.buy(self.datas[0],size=target_size, price=open_price)

                    if signal == -1:
                        total_value = self.broker.get_value()
                        open_price = self.datas[0].open[0]
                        target_size=total_value//open_price
                        #卖出开仓，手数不能超过底仓
                        if target_size>now_hold_size:
                            target_size=now_hold_size

                        self.sell(self.datas[0],size=target_size, price=open_price)

    #订单情况
    def notify_order(self, order):
        
        #订单处于未决，继续
        if order.status in [order.Submitted, order.Accepted]:
            return
        
        #订单已决
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log('买单执行,%.2f' % order.executed.price)

            elif order.issell():
                self.log('卖单执行,%2f' % order.executed.price)
        
        elif order.status in [order.Canceled,order.Rejected,order.Expired]:
            self.log('订单 Canceled/Rejected/Expired')

    #交易情况
    def notify_trade(self, trade):
        if trade.isclosed:
            print('毛收益 %0.2f, 扣佣后收益 % 0.2f , 佣金 %.2f'
            % (trade.pnl, trade.pnlcomm, trade.commission))
        


cerebro=bt.Cerebro()

stock_df=df[['open','high','low','close','volume','openinterest']]
data=bt.feeds.PandasData(dataname=stock_df,fromdate=dt.datetime(2010,1,4),todate=dt.datetime(2021,12,31),timeframe=bt.TimeFrame.Days)
cerebro.adddata(data)

#初始资金设置为10万
cerebro.broker.setcash(100000.0)
#手续费万分之二
cerebro.broker.setcommission(commission=0.0002)
#滑点设置 0.5%
cerebro.broker = bt.brokers.BackBroker(slip_perc=0.005)

cerebro.addstrategy(TestSignalStrategy)
cerebro.addanalyzer(bt.analyzers.PyFolio,_name='PyFolio')

#运行回测
print('start portfolio value:',format(cerebro.broker.getvalue()))
results = cerebro.run()
print('end portfolio value:',format(cerebro.broker.getvalue()))


#绩效评价----------------------------
#获取策略实例
start = results[0]
portfolio_stats = start.analyzers.getbyname('PyFolio')
#以下returns为以日期为索引的资产日收益率序列
returns,positions,transactions,gross_lev = portfolio_stats.get_pf_items()
returns.index = returns.index.tz_convert(None)
# Out:
# start portfolio value: 10000.0
# 2013-08-08,买单执行,2277.25
# 2013-08-22,卖单执行,2302.670000
# 毛收益 101.68, 扣佣后收益  101.68 , 佣金 0.00
# 2013-09-10,买单执行,2446.45
# 2013-09-26,卖单执行,2422.630000
# 毛收益 -95.28, 扣佣后收益 -95.28 , 佣金 0.00
# 2013-10-15,买单执行,2475.32
# 2013-10-25,卖单执行,2400.520000
# 毛收益 -299.20, 扣佣后收益 -299.20 , 佣金 0.00
# 2013-12-05,买单执行,2476.45
# 2013-12-16,卖单执行,2408.680000
# 毛收益 -203.31, 扣佣后收益 -203.31 , 佣金 0.00
# 2014-02-14,买单执行,2278.40
# 2014-02-25,卖单执行,2216.510000
# 毛收益 -247.56, 扣佣后收益 -247.56 , 佣金 0.00
# 2014-04-09,买单执行,2239.79
# 2014-04-22,卖单执行,2184.020000
# 毛收益 -223.08, 扣佣后收益 -223.08 , 佣金 0.00
# 2014-05-29,买单执行,2171.26
# 2014-06-10,卖单执行,2138.670000
# 毛收益 -130.36, 扣佣后收益 -130.36 , 佣金 0.00
# 2014-06-16,买单执行,2176.44
# 2014-06-23,卖单执行,2137.930000
# 毛收益 -154.04, 扣佣后收益 -154.04 , 佣金 0.00
# 2014-07-01,买单执行,2169.20
# 2014-07-14,卖单执行,2149.540000
# 毛收益 -78.64, 扣佣后收益 -78.64 , 佣金 0.00
# 2014-07-24,买单执行,2199.83
# 2014-08-27,卖单执行,2323.790000
# 毛收益 371.88, 扣佣后收益  371.88 , 佣金 0.00
# 2014-09-04,买单执行,2411.93
# 2014-09-18,卖单执行,2396.380000
# 毛收益 -46.65, 扣佣后收益 -46.65 , 佣金 0.00
# 2014-10-09,买单执行,2480.20
# 2014-10-20,卖单执行,2448.450000
# 毛收益 -95.25, 扣佣后收益 -95.25 , 佣金 0.00
# 2014-11-03,买单执行,2515.82
# 2015-01-15,卖单执行,3501.720000
# 毛收益 2957.70, 扣佣后收益  2957.70 , 佣金 0.00
# 2015-02-17,买单执行,3511.54
# 2015-05-07,卖单执行,4520.820000
# 毛收益 3027.84, 扣佣后收益  3027.84 , 佣金 0.00
# 2015-05-27,买单执行,5216.17
# 2015-06-18,卖单执行,5107.690000
# 毛收益 -216.96, 扣佣后收益 -216.96 , 佣金 0.00
# 2015-07-20,买单执行,4157.06
# 2015-07-29,卖单执行,3839.960000
# 毛收益 -951.30, 扣佣后收益 -951.30 , 佣金 0.00
# 2015-08-18,买单执行,4084.31
# 2015-08-21,卖单执行,3714.290000
# 毛收益 -1110.06, 扣佣后收益 -1110.06 , 佣金 0.00
# 2015-10-14,买单执行,3431.14
# 2015-11-04,卖单执行,3477.160000
# 毛收益 138.06, 扣佣后收益  138.06 , 佣金 0.00
# 2015-11-09,买单执行,3796.38
# 2015-11-19,卖单执行,3725.620000
# 毛收益 -212.28, 扣佣后收益 -212.28 , 佣金 0.00
# 2015-12-21,买单执行,3762.10
# 2016-01-04,卖单执行,3725.860000
# 毛收益 -108.72, 扣佣后收益 -108.72 , 佣金 0.00
# 2016-02-18,买单执行,3079.53
# 2016-04-26,卖单执行,3159.770000
# 毛收益 320.96, 扣佣后收益  320.96 , 佣金 0.00
# 2016-05-06,买单执行,3213.14
# 2016-05-16,卖单执行,3064.530000
# 毛收益 -445.83, 扣佣后收益 -445.83 , 佣金 0.00
# 2016-06-02,买单执行,3158.03
# 2016-07-25,卖单执行,3220.170000
# 毛收益 186.42, 扣佣后收益  186.42 , 佣金 0.00
# 2016-08-10,买单执行,3255.18
# 2016-08-25,卖单执行,3314.080000
# 毛收益 176.70, 扣佣后收益  176.70 , 佣金 0.00
# 2016-09-08,买单执行,3338.01
# 2016-09-19,卖单执行,3242.740000
# 毛收益 -285.81, 扣佣后收益 -285.81 , 佣金 0.00
# 2016-10-13,买单执行,3299.16
# 2016-12-09,卖单执行,3464.870000
# 毛收益 497.13, 扣佣后收益  497.13 , 佣金 0.00
# 2017-01-05,买单执行,3368.34
# 2017-01-16,卖单执行,3314.150000
# 毛收益 -162.57, 扣佣后收益 -162.57 , 佣金 0.00
# 2017-01-24,买单执行,3363.14
# 2017-03-03,卖单执行,3424.660000
# 毛收益 184.56, 扣佣后收益  184.56 , 佣金 0.00
# 2017-04-12,买单执行,3514.57
# 2017-04-19,卖单执行,3452.990000
# 毛收益 -184.74, 扣佣后收益 -184.74 , 佣金 0.00
# 2017-05-19,买单执行,3395.23
# 2017-08-11,卖单执行,3687.930000
# 毛收益 878.10, 扣佣后收益  878.10 , 佣金 0.00
# 2017-08-23,买单执行,3747.61
# 2017-09-15,卖单执行,3826.140000
# 毛收益 235.59, 扣佣后收益  235.59 , 佣金 0.00
# 2017-10-11,买单执行,3886.82
# 2017-12-01,卖单执行,4003.560000
# 毛收益 350.22, 扣佣后收益  350.22 , 佣金 0.00
# 2017-12-27,买单执行,4045.28
# 2018-02-02,卖单执行,4213.940000
# 毛收益 505.98, 扣佣后收益  505.98 , 佣金 0.00
# 2018-02-28,买单执行,4016.79
# 2018-03-22,卖单执行,4062.070000
# 毛收益 135.84, 扣佣后收益  135.84 , 佣金 0.00
# 2018-05-10,买单执行,3882.84
# 2018-05-25,卖单执行,3823.740000
# 毛收益 -177.30, 扣佣后收益 -177.30 , 佣金 0.00
# 2018-07-17,买单执行,3466.42
# 2018-08-03,卖单执行,3366.660000
# 毛收益 -399.04, 扣佣后收益 -399.04 , 佣金 0.00
# 2018-08-28,买单执行,3408.15
# 2018-09-06,卖单执行,3286.660000
# 毛收益 -485.96, 扣佣后收益 -485.96 , 佣金 0.00
# 2018-09-21,买单执行,3320.70
# 2018-10-12,卖单执行,3123.370000
# 毛收益 -789.32, 扣佣后收益 -789.32 , 佣金 0.00
# 2018-12-05,买单执行,3224.26
# 2018-12-13,卖单执行,3178.890000
# 毛收益 -136.11, 扣佣后收益 -136.11 , 佣金 0.00
# 2019-01-10,买单执行,3077.48
# 2019-03-29,卖单执行,3739.770000
# 毛收益 2649.16, 扣佣后收益  2649.16 , 佣金 0.00
# 2019-04-04,买单执行,4039.74
# 2019-04-26,卖单执行,3921.890000
# 毛收益 -353.55, 扣佣后收益 -353.55 , 佣金 0.00
# 2019-06-24,买单执行,3836.31
# 2019-07-11,卖单执行,3806.190000
# 毛收益 -90.36, 扣佣后收益 -90.36 , 佣金 0.00
# 2019-07-30,买单执行,3861.57
# 2019-08-06,卖单执行,3609.110000
# 毛收益 -757.38, 扣佣后收益 -757.38 , 佣金 0.00
# 2019-08-20,买单执行,3786.03
# 2019-09-26,卖单执行,3884.700000
# 毛收益 296.01, 扣佣后收益  296.01 , 佣金 0.00
# 2019-10-15,买单执行,3953.16
# 2019-10-24,卖单执行,3877.920000
# 毛收益 -225.72, 扣佣后收益 -225.72 , 佣金 0.00
# 2019-11-04,买单执行,3964.01
# 2019-11-14,卖单执行,3905.930000
# 毛收益 -174.24, 扣佣后收益 -174.24 , 佣金 0.00
# 2019-12-11,买单执行,3907.16
# 2020-02-03,卖单执行,3639.910000
# 毛收益 -801.75, 扣佣后收益 -801.75 , 佣金 0.00
# 2020-02-13,买单执行,3985.88
# 2020-03-17,卖单执行,3739.780000
# 毛收益 -738.30, 扣佣后收益 -738.30 , 佣金 0.00
# 2020-04-10,买单执行,3794.84
# 2020-05-25,卖单执行,3828.320000
# 毛收益 100.44, 扣佣后收益  100.44 , 佣金 0.00
# 2020-06-03,买单执行,4001.17
# 2020-08-13,卖单执行,4666.490000
# 毛收益 1995.96, 扣佣后收益  1995.96 , 佣金 0.00
# 2020-09-02,买单执行,4859.08
# 2020-09-09,卖单执行,4634.250000
# 毛收益 -674.49, 扣佣后收益 -674.49 , 佣金 0.00
# 2020-09-22,买单执行,4654.22
# 2020-09-30,卖单执行,4607.580000
# 毛收益 -93.28, 扣佣后收益 -93.28 , 佣金 0.00
# 2020-10-14,买单执行,4830.46
# 2020-10-23,卖单执行,4775.470000
# 毛收益 -109.98, 扣佣后收益 -109.98 , 佣金 0.00
# 2020-11-05,买单执行,4861.34
# 2020-12-11,卖单执行,4957.820000
# 毛收益 192.96, 扣佣后收益  192.96 , 佣金 0.00
# 2021-01-04,买单执行,5212.93
# 2021-03-01,卖单执行,5389.250000
# 毛收益 352.64, 扣佣后收益  352.64 , 佣金 0.00
# 2021-04-06,买单执行,5178.64
# 2021-04-14,卖单执行,4945.690000
# 毛收益 -465.90, 扣佣后收益 -465.90 , 佣金 0.00
# 2021-04-22,买单执行,5114.28
# 2021-05-10,卖单执行,5001.440000
# 毛收益 -225.68, 扣佣后收益 -225.68 , 佣金 0.00
# 2021-05-20,买单执行,5167.05
# 2021-06-04,卖单执行,5228.280000
# 毛收益 122.46, 扣佣后收益  122.46 , 佣金 0.00
# 2021-06-28,买单执行,5253.61
# 2021-07-27,卖单执行,4924.280000
# 毛收益 -658.66, 扣佣后收益 -658.66 , 佣金 0.00
# 2021-08-06,买单执行,4943.04
# 2021-08-20,卖单执行,4817.490000
# 毛收益 -251.10, 扣佣后收益 -251.10 , 佣金 0.00
# 2021-09-07,买单执行,4932.98
# 2021-09-17,卖单执行,4797.110000
# 毛收益 -271.74, 扣佣后收益 -271.74 , 佣金 0.00
# 2021-12-08,买单执行,4934.41
# 2021-12-21,卖单执行,4876.510000
# 毛收益 -115.80, 扣佣后收益 -115.80 , 佣金 0.00
# end portfolio value: 12530.989999999983

# %%
#画图仍只能在notebook中输出(将basic改成full的话可以得到更多的输出结果，但其中一个return distribution的表会报错)
qs.reports.basic(returns,benchmark=None,rf=0.0,grayscale=False,display=True,compounded = True)
# Out:
# <h4>Performance Metrics</h4>
#                     Strategy
# ------------------  ----------
# Start Period        2013-07-17
# End Period          2021-12-30
# Risk-Free Rate      0.0%
# Time in Market      55.0%
#
# Cumulative Return   25.31%
# CAGR﹪              2.7%
#
# Sharpe              0.28
# Sortino             0.38
# Sortino/√2          0.27
# Omega               1.07
#
# Max Drawdown        -26.23%
# Longest DD Days     1407
#
# Gain/Pain Ratio     0.07
# Gain/Pain (1M)      0.23
#
# Payoff Ratio        1.03
# Profit Factor       1.07
# Common Sense Ratio  1.24
# CPC Index           0.56
# Tail Ratio          1.15
# Outlier Win Ratio   8.68
# Outlier Loss Ratio  3.33
#
# MTD                 -0.92%
# 3M                  -0.92%
# 6M                  -8.55%
# YTD                 -10.78%
# 1Y                  -10.78%
# 3Y (ann.)           -0.78%
# 5Y (ann.)           -0.54%
# 10Y (ann.)          2.7%
# All-time (ann.)     2.7%
#
# Avg. Drawdown       -4.99%
# Avg. Drawdown Days  167
# Recovery Factor     0.97
# Ulcer Index         0.14
# Serenity Index      0.07
# <h4>Strategy Visualization</h4>

# %%
#画图仍只能在notebook中输出
qs.reports.full(returns,benchmark=None,rf=0.0,grayscale=False,display=True,compounded = True)
# Out:
# <h4>Performance Metrics</h4>
#                            Strategy
# -------------------------  ----------
# Start Period               2013-07-17
# End Period                 2021-12-30
# Risk-Free Rate             0.0%
# Time in Market             55.0%
#
# Cumulative Return          25.31%
# CAGR﹪                     2.7%
#
# Sharpe                     0.28
# Smart Sharpe               0.27
# Sortino                    0.38
# Smart Sortino              0.37
# Sortino/√2                 0.27
# Smart Sortino/√2           0.26
# Omega                      1.07
#
# Max Drawdown               -26.23%
# Longest DD Days            1407
# Volatility (ann.)          13.02%
# Calmar                     0.1
# Skew                       -0.93
# Kurtosis                   15.75
#
# Expected Daily %           0.01%
# Expected Monthly %         0.22%
# Expected Yearly %          2.54%
# Kelly Criterion            3.54%
# Risk of Ruin               0.0%
# Daily Value-at-Risk        -1.33%
# Expected Shortfall (cVaR)  -1.33%
#
# Gain/Pain Ratio            0.07
# Gain/Pain (1M)             0.23
#
# Payoff Ratio               1.03
# Profit Factor              1.07
# Common Sense Ratio         1.24
# CPC Index                  0.56
# Tail Ratio                 1.15
# Outlier Win Ratio          8.68
# Outlier Loss Ratio         3.33
#
# MTD                        -0.92%
# 3M                         -0.92%
# 6M                         -8.55%
# YTD                        -10.78%
# 1Y                         -10.78%
# 3Y (ann.)                  -0.78%
# 5Y (ann.)                  -0.54%
# 10Y (ann.)                 2.7%
# All-time (ann.)            2.7%
#
# Best Day                   5.74%
# Worst Day                  -7.55%
# Best Month                 22.24%
# Worst Month                -9.23%
# Best Year                  25.78%
# Worst Year                 -10.78%
#
# Avg. Drawdown              -4.99%
# Avg. Drawdown Days         167
# Recovery Factor            0.97
# Ulcer Index                0.14
# Serenity Index             0.07
#
# Avg. Up Month              4.44%
# Avg. Down Month            -2.42%
# Win Days %                 51.16%
# Win Month %                40.66%
# Win Quarter %              55.88%
# Win Year %                 55.56%
# None
# <h4>5 Worst Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2015-04-28  2016-02-29  2019-03-05  1407    -26.227610        -22.780902
# 2  2019-03-19  2020-04-13  2021-12-30  1017    -21.460948        -21.270132
# 3  2013-09-13  2014-07-10  2014-12-04   447    -16.453534        -16.194876
# 4  2019-03-07  2019-03-08  2019-03-18    11     -4.789171         -3.760748
# 5  2015-01-08  2015-03-06  2015-03-16    67     -4.276015         -4.270887
# <h4>Strategy Visualization</h4>
