# %%
df=pd.read_csv(r'C:\Users\31145\PycharmProjects\Backtrader学习\test_set.csv')#绝对路径
df.index=pd.to_datetime(df.date)
df
# Out:
#                   date         open        close         high          low  \
# date
# 2014-02-06  2014-02-06  21320.91016  21423.13086  21440.40039  21277.00977
# 2014-02-07  2014-02-07  21498.08984  21636.84961  21703.68945  21480.08984
# 2014-02-10  2014-02-10  21646.75000  21579.25977  21687.83984  21524.81055
# 2014-02-11  2014-02-11  21623.78906  21962.98047  22025.58008  21623.78906
# 2014-02-12  2014-02-12  22057.69922  22285.78906  22308.25000  22010.56055
# ...                ...          ...          ...          ...          ...
# 2021-12-22  2021-12-22  23221.13086  23102.33008  23258.71094  22979.75977
# 2021-12-23  2021-12-23  23141.78906  23193.64063  23264.75000  23027.15039
# 2021-12-24  2021-12-24  23375.99023  23223.75977  23383.18945  23186.57031
# 2021-12-28  2021-12-28  23282.34961  23280.56055  23319.43945  23099.48047
# 2021-12-29  2021-12-29  23253.98047  23086.53906  23253.98047  23008.27930
#
#                 volume    return  long_period_return  short_period_return  \
# date
# 2014-02-06  1589901600  0.007229           -0.006583            -0.009236
# 2014-02-07  1698091100  0.009976           -0.002142             0.003735
# 2014-02-10  1718083400 -0.002662           -0.002421             0.004848
# 2014-02-11  2004766000  0.017782           -0.001058             0.008365
# 2014-02-12  1964148900  0.014698            0.001726             0.009939
# ...                ...       ...                 ...                  ...
# 2021-12-22  1230794100  0.005703           -0.005109            -0.001216
# 2021-12-23  1387904000  0.003952           -0.002644             0.006537
# 2021-12-24   622879700  0.001299           -0.001158             0.003651
# 2021-12-28  1433026700  0.002446           -0.001143             0.002566
# 2021-12-29   828414400 -0.008334           -0.000612            -0.001530
#
#             volume_ratio    Sharpe  future_return  signal
# date
# 2014-02-06      1.030037 -0.473550       0.009976      -1
# 2014-02-07      0.941412 -0.159302      -0.002662      -1
# 2014-02-10      0.909527 -0.180305       0.017782      -1
# 2014-02-11      0.975332 -0.070204       0.014698      -1
# 2014-02-12      0.990625  0.107638      -0.005396      -1
# ...                  ...       ...            ...     ...
# 2021-12-22      0.933911 -0.462525       0.003952      -1
# 2021-12-23      0.886689 -0.244023       0.001299      -1
# 2021-12-24      0.737055 -0.110191       0.002446      -1
# 2021-12-28      0.788100 -0.108653      -0.008334      -1
# 2021-12-29      0.761681 -0.061482       0.001103      -1
#
# [1947 rows x 13 columns]

# %%
import pandas as pd
import datetime as dt
import backtrader as bt
import quantstats as qs
import matplotlib as plt
import numpy as np
import os
import pathlib
os.getcwd()

#数据加载-------------------------------------
df=pd.read_csv(pathlib.Path.cwd() / ".." / "data"/ "testCSI300.csv")
df.index=pd.to_datetime(df.date)
df['openinterest']=0

#以下是自己随机添加signal的之后的文件，hmm算法给出的带signal的文件直接用上面的df=pd.read_csv导入，把下面到构建策略之前mute掉即可

# 随机生成一个-1，0，1的predictions序列---------
# sig=[]
# for i in range(len(df)):
#     x=np.random.randn()
#     if x > 0.2:
#         sig.append(1)
#     elif x<-0.2:
#         sig.append(-1)
#     else:
#         sig.append(0)
# df['signal']=sig



#构建策略-------------------------------------
class TestSignalStrategy(bt.Strategy):
    params=()

    def log(self,txt,dt=None):
        dt= dt or self.datas[0].datetime.date(0)
        print('%s,%s' % (dt.isoformat(),txt)) 

    def __init__(self):
        self.bar_num=0
        self.signal_df=df
        self.signal_df['date']=pd.to_datetime(self.signal_df['date'])
        self.first_trade=True

    def prenext(self):
        self.next()

    def next(self):
        self.bar_num+=1
        current_date=self.datas[0].datetime.date(0).strftime("%Y-%m-%d")
        try:
            next_date =self.datas[0].datetime.date(1)
        except:
            next_date=None
        if next_date != None:
            next_signal_df= self.signal_df[self.signal_df['date']==pd.to_datetime(next_date)]
            if len(next_signal_df)==0:
                self.log("下个交易日的信号不存在")
            else:
                signal = int(next_signal_df['signal'])
                
                #第一次交易没有底仓，只允许做多
                #交易信号的执行方式：
                #先不考虑卖空
                #signal为1，以当天开盘价全仓买入
                #signal为-1时，以当天开盘价卖出所有持仓
                if self.first_trade:
                    if signal==-1:
                        pass
                    if signal == 1:
                        total_value = self.broker.get_value()
                        open_price = self.datas[0].open[0]
                        target_size=total_value//open_price
                        self.buy(self.datas[0],size=target_size,price=open_price)
                        self.first_trade=False
                else:
                    #现有持仓
                    now_hold_size = self.getposition(self.datas[0]).size
                    if signal == 1:
                        total_value = self.broker.get_value()
                        open_price = self.datas[0].open[0]
                        target_size=total_value//open_price
                        self.buy(self.datas[0],size=target_size, price=open_price)

                    if signal == -1:
                        total_value = self.broker.get_value()
                        open_price = self.datas[0].open[0]
                        target_size=total_value//open_price
                        #卖出开仓，手数不能超过底仓
                        if target_size>now_hold_size:
                            target_size=now_hold_size

                        self.sell(self.datas[0],size=target_size, price=open_price)

    #订单情况
    def notify_order(self, order):
        
        #订单处于未决，继续
        if order.status in [order.Submitted, order.Accepted]:
            return
        
        #订单已决
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log('买单执行,%.2f' % order.executed.price)

            elif order.issell():
                self.log('卖单执行,%2f' % order.executed.price)
        
        elif order.status in [order.Canceled,order.Rejected,order.Expired]:
            self.log('订单 Canceled/Rejected/Expired')

    #交易情况
    def notify_trade(self, trade):
        if trade.isclosed:
            print('毛收益 %0.2f, 扣佣后收益 % 0.2f , 佣金 %.2f'
            % (trade.pnl, trade.pnlcomm, trade.commission))
        


cerebro=bt.Cerebro()

stock_df=df[['open','high','low','close','volume','openinterest']]

# %%
data=bt.feeds.PandasData(dataname=stock_df,fromdate=dt.datetime(2014, 2, 6), todate=dt.datetime(2021, 12, 29),timeframe=bt.TimeFrame.Days)
cerebro.adddata(data)

#初始资金设置为10万
cerebro.broker.setcash(100000.0)
#手续费万分之二
cerebro.broker.setcommission(commission=0.0002)
#滑点设置 0.5%
cerebro.broker.set_slippage_perc(0.005,slip_open=True,slip_limit=True,slip_match=True,slip_out=False)

cerebro.addstrategy(TestSignalStrategy)
cerebro.addanalyzer(bt.analyzers.PyFolio,_name='PyFolio')

#运行回测
print('start portfolio value:',format(cerebro.broker.getvalue()))
results = cerebro.run()
print('end portfolio value:',format(cerebro.broker.getvalue()))


#绩效评价----------------------------
#获取策略实例
start = results[0]
portfolio_stats = start.analyzers.getbyname('PyFolio')
#以下returns为以日期为索引的资产日收益率序列
returns,positions,transactions,gross_lev = portfolio_stats.get_pf_items()
returns.index = returns.index.tz_convert(None)
# Out:
# start portfolio value: 100000.0
# 2014-03-27,买单执行,2179.18
# 2014-04-04,卖单执行,2155.280000
# 毛收益 -1075.58, 扣佣后收益 -1114.59 , 佣金 39.01
# 2014-04-08,买单执行,2190.82
# 2014-04-21,卖单执行,2198.890300
# 毛收益 363.18, 扣佣后收益  323.67 , 佣金 39.51
# 2014-05-14,买单执行,2184.22
# 2014-05-22,卖单执行,2128.860000
# 毛收益 -2491.20, 扣佣后收益 -2530.02 , 佣金 38.82
# 2014-05-30,买单执行,2166.91
# 2014-06-05,卖单执行,2123.520000
# 毛收益 -1909.16, 扣佣后收益 -1946.92 , 佣金 37.76
# 2014-06-13,买单执行,2161.74
# 2014-06-20,卖单执行,2120.810000
# 毛收益 -1760.20, 扣佣后收益 -1797.03 , 佣金 36.83
# 2014-07-02,买单执行,2171.51
# 2014-07-11,卖单执行,2134.800000
# 毛收益 -1541.82, 扣佣后收益 -1577.99 , 佣金 36.17
# 2014-07-21,买单执行,2171.94
# 2014-08-15,卖单执行,2333.120000
# 2014-08-18,卖单执行,2361.200000
# 毛收益 6797.64, 扣佣后收益  6759.79 , 佣金 37.85
# 2014-08-19,买单执行,2379.47
# 2014-08-27,卖单执行,2322.890000
# 2014-08-28,卖单执行,2316.419700
# 毛收益 -2326.25, 扣佣后收益 -2364.81 , 佣金 38.56
# 2014-09-05,买单执行,2445.34
# 2014-09-17,卖单执行,2383.383200
# 2014-09-18,卖单执行,2389.620000
# 毛收益 -2409.92, 扣佣后收益 -2447.58 , 佣金 37.67
# 2014-09-26,买单执行,2439.65
# 2014-10-20,卖单执行,2441.900000
# 毛收益 85.50, 扣佣后收益  48.40 , 佣金 37.10
# 2014-11-04,买单执行,2517.46
# 2014-11-21,卖单执行,2530.030000
# 毛收益 465.09, 扣佣后收益  427.74 , 佣金 37.35
# 2014-11-25,买单执行,2663.34
# 2014-12-18,卖单执行,3342.294550
# 毛收益 23763.39, 扣佣后收益  23721.35 , 佣金 42.04
# 2014-12-19,买单执行,3362.36
# 2014-12-30,卖单执行,3433.555950
# 毛收益 2420.73, 扣佣后收益  2374.51 , 佣金 46.21
# 2015-01-06,买单执行,3626.47
# 2015-01-15,卖单执行,3484.211400
# 2015-01-16,卖单执行,3601.260000
# 毛收益 -4577.56, 扣佣后收益 -4624.51 , 佣金 46.95
# 2015-01-29,买单执行,3492.28
# 2015-02-02,卖单执行,3347.090000
# 毛收益 -4646.23, 扣佣后收益 -4690.00 , 佣金 43.77
# 2015-02-17,买单执行,3529.10
# 2015-03-10,卖单执行,3511.990000
# 毛收益 -530.34, 扣佣后收益 -573.99 , 佣金 43.65
# 2015-03-13,买单执行,3622.69
# 2015-05-06,卖单执行,4603.098850
# 2015-05-07,卖单执行,4498.215900
# 毛收益 29307.28, 扣佣后收益  29257.95 , 佣金 49.33
# 2015-05-15,买单执行,4690.76
# 2015-06-01,卖单执行,4838.446200
# 毛收益 4282.90, 扣佣后收益  4227.63 , 佣金 55.27
# 2015-06-10,买单执行,5280.57
# 2015-06-17,卖单执行,5046.948450
# 毛收益 -6074.20, 扣佣后收益 -6127.90 , 佣金 53.70
# 2015-07-21,买单执行,4130.31
# 2015-07-22,卖单执行,4127.817200
# 毛收益 -82.22, 扣佣后收益 -136.73 , 佣金 54.50
# 2015-07-27,买单执行,4118.29
# 2015-07-28,卖单执行,3672.515150
# 2015-07-29,卖单执行,3820.760200
# 毛收益 -14116.52, 扣佣后收益 -14166.41 , 佣金 49.89
# 2015-08-12,买单执行,4045.80
# 2015-08-19,卖单执行,3729.528650
# 2015-08-20,卖单执行,3829.158000
# 毛收益 -9288.83, 扣佣后收益 -9335.52 , 佣金 46.69
# 2015-09-08,买单执行,3237.90
# 2015-09-11,卖单执行,3333.130600
# 毛收益 3142.64, 扣佣后收益  3099.28 , 佣金 43.37
# 2015-09-25,买单执行,3289.02
# 2015-09-28,卖单执行,3210.476950
# 毛收益 -2749.12, 扣佣后收益 -2794.62 , 佣金 45.50
# 2015-10-14,买单执行,3448.30
# 2015-11-04,卖单执行,3477.160000
# 2015-11-05,卖单执行,3627.300000
# 毛收益 1102.66, 扣佣后收益  1056.92 , 佣金 45.74
# 2015-11-10,买单执行,3825.70
# 2015-11-19,卖单执行,3714.680000
# 2015-11-20,卖单执行,3759.985600
# 毛收益 -3285.39, 扣佣后收益 -3330.65 , 佣金 45.25
# 2015-12-09,买单执行,3631.49
# 2015-12-14,卖单执行,3571.000000
# 毛收益 -1814.61, 扣佣后收益 -1857.83 , 佣金 43.21
# 2015-12-18,买单执行,3773.73
# 2015-12-31,卖单执行,3742.095500
# 毛收益 -917.54, 扣佣后收益 -961.13 , 佣金 43.59
# 2016-02-18,买单执行,3093.51
# 2016-02-26,卖单执行,2927.389500
# 2016-02-29,卖单执行,2924.882100
# 毛收益 -5819.23, 扣佣后收益 -5861.38 , 佣金 42.15
# 2016-03-08,买单执行,3109.25
# 2016-03-16,卖单执行,3064.520000
# 毛收益 -1476.09, 扣佣后收益 -1516.84 , 佣金 40.75
# 2016-03-18,买单执行,3151.90
# 2016-03-31,卖单执行,3213.054000
# 毛收益 1956.89, 扣佣后收益  1916.16 , 佣金 40.74
# 2016-04-07,买单执行,3270.82
# 2016-04-21,卖单执行,3150.940000
# 毛收益 -3716.28, 扣佣后收益 -3756.09 , 佣金 39.81
# 2016-06-02,买单执行,3168.82
# 2016-06-14,卖单执行,3055.660000
# 2016-06-15,卖单执行,3042.230000
# 毛收益 -3521.39, 扣佣后收益 -3559.98 , 佣金 38.59
# 2016-06-24,买单执行,3126.20
# 2016-06-27,卖单执行,3064.970000
# 毛收益 -1837.00, 扣佣后收益 -1874.14 , 佣金 37.15
# 2016-06-28,买单执行,3122.94
# 2016-07-22,卖单执行,3234.983800
# 毛收益 3361.40, 扣佣后收益  3323.26 , 佣金 38.15
# 2016-08-11,买单执行,3255.76
# 2016-08-25,卖单执行,3297.509600
# 毛收益 1210.80, 扣佣后收益  1172.79 , 佣金 38.01
# 2016-09-07,买单执行,3357.36
# 2016-09-13,卖单执行,3249.013300
# 毛收益 -3142.05, 扣佣后收益 -3180.37 , 佣金 38.32
# 2016-10-12,买单执行,3302.56
# 2016-11-03,卖单执行,3324.840000
# 毛收益 623.84, 扣佣后收益  586.73 , 佣金 37.11
# 2016-11-08,买单执行,3383.92
# 2016-12-07,卖单执行,3445.760000
# 毛收益 1731.52, 扣佣后收益  1693.27 , 佣金 38.25
# 2017-01-05,买单执行,3373.41
# 2017-01-13,卖单执行,3309.370000
# 2017-01-16,卖单执行,3297.579250
# 毛收益 -1868.95, 扣佣后收益 -1907.71 , 佣金 38.76
# 2017-01-24,买单执行,3371.32
# 2017-03-03,卖单执行,3412.830000
# 毛收益 1162.28, 扣佣后收益  1124.29 , 佣金 37.99
# 2017-03-15,买单执行,3463.92
# 2017-03-31,卖单执行,3430.820000
# 2017-04-18,卖单执行,3462.630000
# 毛收益 -894.99, 扣佣后收益 -933.61 , 佣金 38.62
# 2017-05-18,买单执行,3404.61
# 2017-06-21,卖单执行,3549.294350
# 毛收益 4051.21, 扣佣后收益  4012.27 , 佣金 38.94
# 2017-06-26,买单执行,3645.16
# 2017-08-11,卖单执行,3669.490350
# 毛收益 657.05, 扣佣后收益  617.55 , 佣金 39.50
# 2017-08-23,买单执行,3766.35
# 2017-09-15,卖单执行,3818.520000
# 毛收益 1356.47, 扣佣后收益  1317.03 , 佣金 39.44
# 2017-09-19,买单执行,3857.30
# 2017-09-26,卖单执行,3808.380000
# 毛收益 -1271.92, 扣佣后收益 -1311.78 , 佣金 39.86
# 2017-10-10,买单执行,3900.74
# 2017-11-29,卖单执行,4041.043250
# 毛收益 3507.58, 扣佣后收益  3467.87 , 佣金 39.71
# 2017-12-22,买单执行,4076.80
# 2018-02-01,卖单执行,4254.958300
# 毛收益 4453.96, 扣佣后收益  4412.30 , 佣金 41.66
# 2018-02-28,买单执行,4036.87
# 2018-03-07,卖单执行,4043.182500
# 毛收益 164.02, 扣佣后收益  122.01 , 佣金 42.02
# 2018-03-12,买单执行,4139.53
# 2018-03-21,卖单执行,4076.534900
# 毛收益 -1637.87, 扣佣后收益 -1680.60 , 佣金 42.72
# 2018-04-11,买单执行,3953.84
# 2018-04-17,卖单执行,3793.805650
# 2018-04-18,卖单执行,3766.383450
# 毛收益 -4348.37, 扣佣后收益 -4390.20 , 佣金 41.83
# 2018-05-10,买单执行,3894.49
# 2018-05-24,卖单执行,3834.023550
# 毛收益 -1572.13, 扣佣后收益 -1612.32 , 佣金 40.19
# 2018-06-11,买单执行,3789.06
# 2018-06-12,卖单执行,3765.260000
# 毛收益 -618.83, 扣佣后收益 -658.11 , 佣金 39.28
# 2018-06-13,买单执行,3817.45
# 2018-06-15,卖单执行,3744.224800
# 毛收益 -1903.86, 扣佣后收益 -1943.18 , 佣金 39.32
# 2018-07-16,买单执行,3506.24
# 2018-07-20,卖单执行,3409.327700
# 2018-08-02,卖单执行,3417.178250
# 毛收益 -2705.69, 扣佣后收益 -2744.42 , 佣金 38.73
# 2018-08-16,买单执行,3268.12
# 2018-08-17,卖单执行,3289.370500
# 毛收益 595.03, 扣佣后收益  558.31 , 佣金 36.72
# 2018-08-28,买单执行,3416.59
# 2018-09-06,卖单执行,3270.226700
# 2018-09-07,卖单执行,3257.520550
# 毛收益 -4110.88, 扣佣后收益 -4148.32 , 佣金 37.44
# 2018-09-21,买单执行,3337.30
# 2018-10-11,卖单执行,3163.642300
# 毛收益 -4688.85, 扣佣后收益 -4723.96 , 佣金 35.11
# 2018-10-24,买单执行,3185.31
# 2018-11-01,卖单执行,3173.100000
# 毛收益 -317.39, 扣佣后收益 -350.45 , 佣金 33.06
# 2018-11-05,买单执行,3279.88
# 2018-11-14,卖单执行,3217.471800
# 毛收益 -1622.61, 扣佣后收益 -1656.40 , 佣金 33.79
# 2018-11-19,买单执行,3275.08
# 2018-11-27,卖单执行,3137.006150
# 毛收益 -3590.02, 扣佣后收益 -3623.37 , 佣金 33.34
# 2018-12-04,买单执行,3267.94
# 2018-12-13,卖单执行,3169.420000
# 2018-12-14,卖单执行,3191.313250
# 毛收益 -2441.11, 扣佣后收益 -2473.30 , 佣金 32.19
# 2019-01-08,买单执行,3055.51
# 2019-03-11,卖单执行,3650.810000
# 毛收益 14882.50, 扣佣后收益  14848.97 , 佣金 33.53
# 2019-03-20,买单执行,3844.47
# 2019-03-28,卖单执行,3712.404700
# 毛收益 -3169.49, 扣佣后收益 -3205.76 , 佣金 36.27
# 2019-04-03,买单执行,3967.61
# 2019-04-26,卖单执行,3902.280550
# 毛收益 -1437.23, 扣佣后收益 -1471.86 , 佣金 34.63
# 2019-06-04,买单执行,3636.13
# 2019-06-06,卖单执行,3583.034800
# 毛收益 -1274.28, 扣佣后收益 -1308.94 , 佣金 34.65
# 2019-06-13,买单执行,3697.59
# 2019-07-11,卖单执行,3787.159050
# 毛收益 2060.09, 扣佣后收益  2025.66 , 佣金 34.43
# 2019-07-29,买单执行,3862.75
# 2019-08-05,卖单执行,3705.787950
# 毛收益 -3610.13, 扣佣后收益 -3644.94 , 佣金 34.82
# 2019-08-16,买单执行,3716.43
# 2019-09-19,卖单执行,3904.340200
# 毛收益 4321.94, 扣佣后收益  4286.89 , 佣金 35.06
# 2019-10-16,买单执行,3958.98
# 2019-10-24,卖单执行,3858.530400
# 毛收益 -2209.81, 扣佣后收益 -2244.21 , 佣金 34.40
# 2019-10-30,买单执行,3908.10
# 2019-11-13,卖单执行,3885.753600
# 毛收益 -491.62, 扣佣后收益 -525.91 , 佣金 34.29
# 2019-12-09,买单执行,3911.97
# 2019-12-27,卖单执行,4019.720000
# 毛收益 2370.50, 扣佣后收益  2335.60 , 佣金 34.90
# 2019-12-31,买单执行,4098.14
# 2020-01-23,卖单执行,4072.853400
# 毛收益 -556.28, 扣佣后收益 -592.23 , 佣金 35.95
# 2020-02-13,买单执行,3999.55
# 2020-03-02,卖单执行,3968.840000
# 毛收益 -675.62, 扣佣后收益 -710.68 , 佣金 35.06
# 2020-04-01,买单执行,3700.71
# 2020-05-20,卖单执行,3935.931450
# 毛收益 5645.28, 扣佣后收益  5608.62 , 佣金 36.66
# 2020-06-03,买单执行,4018.68
# 2020-06-19,卖单执行,4043.490000
# 毛收益 570.63, 扣佣后收益  533.54 , 佣金 37.09
# 2020-06-22,买单执行,4118.00
# 2020-07-17,卖单执行,4502.146150
# 2020-07-20,卖单执行,4574.214000
# 毛收益 8907.49, 扣佣后收益  8867.82 , 佣金 39.67
# 2020-08-05,买单执行,4785.57
# 2020-08-13,卖单执行,4643.157550
# 毛收益 -2990.64, 扣佣后收益 -3030.24 , 佣金 39.60
# 2020-08-20,买单执行,4721.44
# 2020-08-27,卖单执行,4694.469700
# 毛收益 -566.38, 扣佣后收益 -605.92 , 佣金 39.55
# 2020-09-01,买单执行,4827.41
# 2020-09-09,卖单执行,4611.078750
# 毛收益 -4326.56, 扣佣后收益 -4364.32 , 佣金 37.75
# 2020-09-21,买单执行,4752.98
# 2020-09-25,卖单执行,4559.567600
# 2020-09-28,卖单执行,4571.150000
# 毛收益 -3856.67, 扣佣后收益 -3893.92 , 佣金 37.25
# 2020-10-13,买单执行,4836.96
# 2020-10-23,卖单执行,4751.592650
# 毛收益 -1622.07, 扣佣后收益 -1658.50 , 佣金 36.44
# 2020-11-05,买单执行,4885.11
# 2020-11-19,卖单执行,4870.200000
# 毛收益 -268.38, 扣佣后收益 -303.50 , 佣金 35.12
# 2020-11-24,买单执行,5001.06
# 2020-12-11,卖单执行,4933.030900
# 毛收益 -1224.52, 扣佣后收益 -1260.29 , 佣金 35.76
# 2020-12-22,买单执行,5055.13
# 2021-01-22,卖单执行,5534.568100
# 毛收益 8150.45, 扣佣后收益  8114.44 , 佣金 36.00
# 2021-01-26,买单执行,5600.90
# 2021-02-01,卖单执行,5342.050000
# 毛收益 -4400.45, 扣佣后收益 -4437.66 , 佣金 37.21
# 2021-02-09,买单执行,5612.09
# 2021-02-24,卖单执行,5563.522600
# 毛收益 -777.09, 扣佣后收益 -812.85 , 佣金 35.76
# 2021-03-19,买单执行,5089.92
# 2021-03-23,卖单执行,5031.774700
# 毛收益 -988.47, 扣佣后收益 -1022.88 , 佣金 34.41
# 2021-04-06,买单执行,5181.15
# 2021-04-12,卖单执行,5001.845100
# 毛收益 -3048.18, 扣佣后收益 -3082.81 , 佣金 34.62
# 2021-04-22,买单执行,5119.22
# 2021-05-10,卖单执行,4976.432800
# 2021-05-11,卖单执行,4931.299600
# 毛收益 -2472.52, 扣佣后收益 -2506.83 , 佣金 34.32
# 2021-05-19,买单执行,5193.56
# 2021-06-04,卖单执行,5221.230000
# 毛收益 442.72, 扣佣后收益  409.39 , 佣金 33.33
# 2021-06-28,买单执行,5260.64
# 2021-07-06,卖单执行,5064.331100
# 毛收益 -3140.94, 扣佣后收益 -3173.98 , 佣金 33.04
# 2021-07-14,买单执行,5130.75
# 2021-07-27,卖单执行,4899.658600
# 2021-07-28,卖单执行,4690.718550
# 毛收益 -3906.40, 扣佣后收益 -3938.46 , 佣金 32.06
# 2021-08-06,买单执行,4944.35
# 2021-08-18,卖单执行,4818.900000
# 毛收益 -1881.75, 扣佣后收益 -1911.04 , 佣金 29.29
# 2021-09-02,买单执行,4890.15
# 2021-09-17,卖单执行,4786.090000
# 毛收益 -1560.89, 扣佣后收益 -1589.92 , 佣金 29.03
# 2021-10-11,买单执行,4966.00
# 2021-10-29,卖单执行,4855.760000
# 毛收益 -1653.55, 扣佣后收益 -1683.01 , 佣金 29.47
# 2021-11-15,买单执行,4906.33
# 2021-12-01,卖单执行,4823.930000
# 毛收益 -1153.60, 扣佣后收益 -1180.84 , 佣金 27.24
# 2021-12-08,买单执行,4959.08
# 2021-12-21,卖单执行,4872.950000
# 毛收益 -1205.85, 扣佣后收益 -1233.38 , 佣金 27.53
# end portfolio value: 70972.39112902035

# %%
#画图仍只能在notebook中输出(将basic改成full的话可以得到更多的输出结果，但其中一个return distribution的表会报错)
qs.reports.basic(returns,rf=0.0,grayscale=False,display=True,compounded = True)
#只有在full中有和benchmark的对比
qs.reports.full(returns,benchmark=stock_df['close'],rf=0.0,grayscale=False,display=True,compounded = True)
# Out:
# <h4>Performance Metrics</h4>
#                     Strategy
# ------------------  ----------
# Start Period        2014-03-07
# End Period          2021-12-29
# Risk-Free Rate      0.0%
# Time in Market      60.0%
#
# Cumulative Return   -29.03%
# CAGR﹪              -4.29%
#
# Sharpe              -0.25
# Sortino             -0.35
# Sortino/√2          -0.25
# Omega               0.94
#
# Max Drawdown        -53.9%
# Longest DD Days     2408
#
# Gain/Pain Ratio     -0.06
# Gain/Pain (1M)      -0.16
#
# Payoff Ratio        1.15
# Profit Factor       0.94
# Common Sense Ratio  1.02
# CPC Index           0.49
# Tail Ratio          1.09
# Outlier Win Ratio   8.26
# Outlier Loss Ratio  3.96
#
# MTD                 -1.88%
# 3M                  -5.46%
# 6M                  -17.01%
# YTD                 -22.57%
# 1Y                  -20.4%
# 3Y (ann.)           -3.66%
# 5Y (ann.)           -6.22%
# 10Y (ann.)          -4.29%
# All-time (ann.)     -4.29%
#
# Avg. Drawdown       -7.08%
# Avg. Drawdown Days  199
# Recovery Factor     -0.54
# Ulcer Index         0.35
# Serenity Index      -0.01
# <h4>Strategy Visualization</h4>
# C:\Python\Python38\lib\site-packages\numpy\core\fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# <h4>Performance Metrics</h4>
#                            Strategy    Benchmark
# -------------------------  ----------  -----------
# Start Period               2014-03-07  2014-03-07
# End Period                 2021-12-29  2021-12-29
# Risk-Free Rate             0.0%        0.0%
# Time in Market             60.0%       5.0%
#
# Cumulative Return          -29.03%     -100.0%
# CAGR﹪                     -4.29%      -100.0%
#
# Sharpe                     -0.25       -0.35
# Smart Sharpe               -0.24       -0.33
# Sortino                    -0.35       -0.35
# Smart Sortino              -0.33       -0.33
# Sortino/√2                 -0.25       -0.25
# Smart Sortino/√2           -0.23       -0.23
# Omega                      0.94        0.94
#
# Max Drawdown               -53.9%      -100.0%
# Longest DD Days            2408        2819
# Volatility (ann.)          14.03%      36.48%
# R^2                        0.0         0.0
# Calmar                     -0.08       -1.0
# Skew                       -0.45       -43.21
# Kurtosis                   11.31       1880.51
#
# Expected Daily %           -0.02%      -100.0%
# Expected Monthly %         -0.36%      -100.0%
# Expected Yearly %          -4.2%       -100.0%
# Kelly Criterion            -11.74%     -6.06%
# Risk of Ruin               0.0%        0.0%
# Daily Value-at-Risk        -1.47%      -3.83%
# Expected Shortfall (cVaR)  -1.47%      -3.83%
#
# Gain/Pain Ratio            -0.06       -0.76
# Gain/Pain (1M)             -0.16       -0.96
#
# Payoff Ratio               0.97        1.08
# Profit Factor              0.94        0.24
# Common Sense Ratio         1.02        nan
# CPC Index                  0.41        0.12
# Tail Ratio                 1.09        nan
# Outlier Win Ratio          5.2         106.48
# Outlier Loss Ratio         2.42        0.69
#
# MTD                        -1.88%      0.0%
# 3M                         -5.46%      0.0%
# 6M                         -17.01%     0.0%
# YTD                        -22.57%     0.0%
# 1Y                         -20.4%      0.0%
# 3Y (ann.)                  -3.66%      0.0%
# 5Y (ann.)                  -6.22%      0.0%
# 10Y (ann.)                 -4.29%      -100.0%
# All-time (ann.)            -4.29%      -100.0%
#
# Best Day                   5.76%       3.44%
# Worst Day                  -7.01%      -100.0%
# Best Month                 21.27%      2.31%
# Worst Month                -10.41%     -100.0%
# Best Year                  19.88%      0.0%
# Worst Year                 -23.03%     -100.0%
#
# Avg. Drawdown              -7.08%      -21.11%
# Avg. Drawdown Days         199         567
# Recovery Factor            -0.54       -1.0
# Ulcer Index                0.35        0.98
# Serenity Index             -0.01       -0.02
#
# Avg. Up Month              0.72%       0.58%
# Avg. Down Month            -3.03%      -0.1%
# Win Days %                 45.01%      45.05%
# Win Month %                37.36%      60.0%
# Win Quarter %              40.62%      66.67%
# Win Year %                 50.0%       0.0%
# Beta                       -0.01       -
# Alpha                      -0.04       -
# None
# <h4>5 Worst Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2015-05-27  2021-12-21  2021-12-29  2408    -53.900686        -52.773500
# 2  2014-04-11  2014-07-21  2014-12-02   235    -11.204905        -10.609224
# 3  2014-12-30  2015-03-06  2015-03-30    90     -9.674758         -9.669362
# 4  2015-04-28  2015-05-18  2015-05-22    24     -6.629915         -5.786301
# 5  2014-12-23  2014-12-24  2014-12-26     3     -4.705236         -1.994614
# <h4>Strategy Visualization</h4>
