# %%
import pandas as pd
import datetime as dt
import backtrader as bt
import quantstats as qs
import matplotlib as plt
import numpy as np
import os
import pathlib
os.getcwd()

#数据加载-------------------------------------
df=pd.read_csv(pathlib.Path.cwd() / ".." / "data"/ "testCSI300.csv")#绝对路径
df.index=pd.to_datetime(df.date)
df['openinterest']=0

#以下是自己随机添加signal的之后的文件，hmm算法给出的带signal的文件直接用上面的df=pd.read_csv导入，把下面到构建策略之前mute掉即可

# 随机生成一个-1，0，1的predictions序列---------
# sig=[]
# for i in range(len(df)):
#     x=np.random.randn()
#     if x > 0.2:
#         sig.append(1)
#     elif x<-0.2:
#         sig.append(-1)
#     else:
#         sig.append(0)
# df['signal']=sig



#构建策略-------------------------------------
class TestSignalStrategy(bt.Strategy):
    params=()

    def log(self,txt,dt=None):
        dt= dt or self.datas[0].datetime.date(0)
        print('%s,%s' % (dt.isoformat(),txt)) 

    def __init__(self):
        self.bar_num=0
        self.signal_df=df
        self.signal_df['date']=pd.to_datetime(self.signal_df['date'])
        self.first_trade=True

    def prenext(self):
        self.next()

    def next(self):
        self.bar_num+=1
        current_date=self.datas[0].datetime.date(0).strftime("%Y-%m-%d")
        try:
            next_date =self.datas[0].datetime.date(1)
        except:
            next_date=None
        if next_date != None:
            next_signal_df= self.signal_df[self.signal_df['date']==pd.to_datetime(next_date)]
            if len(next_signal_df)==0:
                self.log("下个交易日的信号不存在")
            else:
                signal = int(next_signal_df['signal'])
                
                #第一次交易没有底仓，只允许做多
                #交易信号的执行方式：
                #先不考虑卖空
                #signal为1，以当天开盘价全仓买入
                #signal为-1时，以当天开盘价卖出所有持仓
                if self.first_trade:
                    if signal==-1:
                        pass
                    if signal == 1:
                        total_value = self.broker.get_value()
                        open_price = self.datas[0].open[0]
                        target_size=total_value//open_price
                        self.buy(self.datas[0],size=target_size,price=open_price)
                        self.first_trade=False
                else:
                    #现有持仓
                    now_hold_size = self.getposition(self.datas[0]).size
                    if signal == 1:
                        total_value = self.broker.get_value()
                        open_price = self.datas[0].open[0]
                        target_size=total_value//open_price
                        self.buy(self.datas[0],size=target_size, price=open_price)

                    if signal == -1:
                        total_value = self.broker.get_value()
                        open_price = self.datas[0].open[0]
                        target_size=total_value//open_price
                        #卖出开仓，手数不能超过底仓
                        if target_size>now_hold_size:
                            target_size=now_hold_size

                        self.sell(self.datas[0],size=target_size, price=open_price)

    #订单情况
    def notify_order(self, order):
        
        #订单处于未决，继续
        if order.status in [order.Submitted, order.Accepted]:
            return
        
        #订单已决
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log('买单执行,%.2f' % order.executed.price)

            elif order.issell():
                self.log('卖单执行,%2f' % order.executed.price)
        
        elif order.status in [order.Canceled,order.Rejected,order.Expired]:
            self.log('订单 Canceled/Rejected/Expired')

    #交易情况
    def notify_trade(self, trade):
        if trade.isclosed:
            print('毛收益 %0.2f, 扣佣后收益 % 0.2f , 佣金 %.2f'
            % (trade.pnl, trade.pnlcomm, trade.commission))
        


cerebro=bt.Cerebro()

stock_df=df[['open','high','low','close','volume','openinterest']]

# %%
data=bt.feeds.PandasData(dataname=stock_df,timeframe=bt.TimeFrame.Days)
cerebro.adddata(data)

#初始资金设置为10万
cerebro.broker.setcash(100000.0)
#手续费万分之二
cerebro.broker.setcommission(commission=0.0002)
#滑点设置 0.5%
cerebro.broker.set_slippage_perc(0.005,slip_open=True,slip_limit=True,slip_match=True,slip_out=False)

cerebro.addstrategy(TestSignalStrategy)
cerebro.addanalyzer(bt.analyzers.PyFolio,_name='PyFolio')

#运行回测
print('start portfolio value:',format(cerebro.broker.getvalue()))
results = cerebro.run()
print('end portfolio value:',format(cerebro.broker.getvalue()))


#绩效评价----------------------------
#获取策略实例
start = results[0]
portfolio_stats = start.analyzers.getbyname('PyFolio')
#以下returns为以日期为索引的资产日收益率序列
returns,positions,transactions,gross_lev = portfolio_stats.get_pf_items()
returns.index = returns.index.tz_convert(None)
# Out:
# start portfolio value: 100000.0
# 2014-03-10,买单执行,2149.68
# 2014-03-11,卖单执行,2088.730000
# 2014-03-12,卖单执行,2092.286000
# 毛收益 -2800.14, 扣佣后收益 -2839.14 , 佣金 38.99
# 2014-03-25,买单执行,2181.63
# 2014-04-04,卖单执行,2155.280000
# 毛收益 -1159.57, 扣佣后收益 -1197.74 , 佣金 38.16
# 2014-04-10,买单执行,2252.66
# 2014-04-22,卖单执行,2173.099900
# 毛收益 -3341.41, 扣佣后收益 -3378.59 , 佣金 37.18
# 2014-05-14,买单执行,2184.22
# 2014-05-22,卖单执行,2128.860000
# 毛收益 -2325.12, 扣佣后收益 -2361.35 , 佣金 36.23
# 2014-05-30,买单执行,2166.91
# 2014-06-05,卖单执行,2123.520000
# 毛收益 -1778.99, 扣佣后收益 -1814.17 , 佣金 35.18
# 2014-06-13,买单执行,2161.74
# 2014-06-20,卖单执行,2120.810000
# 毛收益 -1637.40, 扣佣后收益 -1671.66 , 佣金 34.26
# 2014-07-02,买单执行,2171.51
# 2014-07-11,卖单执行,2134.800000
# 毛收益 -1431.69, 扣佣后收益 -1465.28 , 佣金 33.59
# 2014-07-22,买单执行,2173.25
# 2014-08-14,卖单执行,2345.414000
# 毛收益 6714.31, 扣佣后收益  6679.06 , 佣金 35.25
# 2014-08-19,买单执行,2379.47
# 2014-08-26,卖单执行,2327.902000
# 毛收益 -1959.58, 扣佣后收益 -1995.36 , 佣金 35.78
# 2014-09-04,买单执行,2423.99
# 2014-09-17,卖单执行,2383.383200
# 2014-09-18,卖单执行,2389.620000
# 毛收益 -1496.20, 扣佣后收益 -1531.78 , 佣金 35.58
# 2014-10-09,买单执行,2488.11
# 2014-10-20,卖单执行,2441.900000
# 毛收益 -1617.35, 扣佣后收益 -1651.86 , 佣金 34.51
# 2014-11-04,买单执行,2517.46
# 2014-11-20,卖单执行,2522.840000
# 毛收益 182.92, 扣佣后收益  148.65 , 佣金 34.27
# 2014-11-26,买单执行,2708.74
# 2014-12-17,卖单执行,3309.190900
# 毛收益 19214.55, 扣佣后收益  19176.03 , 佣金 38.51
# 2014-12-19,买单执行,3362.36
# 2014-12-25,卖单执行,3238.207600
# 2014-12-26,卖单执行,3335.010000
# 毛收益 -3751.86, 扣佣后收益 -3792.81 , 佣金 40.94
# 2015-01-06,买单执行,3626.47
# 2015-01-09,卖单执行,3536.390000
# 2015-01-15,卖单执行,3484.211400
# 毛收益 -2574.48, 扣佣后收益 -2614.58 , 佣金 40.10
# 2015-01-29,买单执行,3492.28
# 2015-02-02,卖单执行,3347.090000
# 毛收益 -4065.45, 扣佣后收益 -4103.75 , 佣金 38.30
# 2015-02-17,买单执行,3529.10
# 2015-03-06,卖单执行,3483.674100
# 2015-03-09,卖单执行,3432.451500
# 毛收益 -1277.66, 扣佣后收益 -1315.52 , 佣金 37.86
# 2015-03-17,买单执行,3752.63
# 2015-05-05,卖单执行,4761.264050
# 毛收益 25215.86, 扣佣后收益  25173.29 , 佣金 42.57
# 2015-05-28,买单执行,5199.97
# 2015-05-29,卖单执行,4815.332350
# 2015-06-01,卖单执行,4838.446200
# 毛收益 -8438.93, 扣佣后收益 -8483.00 , 佣金 44.07
# 2015-06-10,买单执行,5280.57
# 2015-06-17,卖单执行,5046.948450
# 毛收益 -4672.46, 扣佣后收益 -4713.77 , 佣金 41.31
# 2015-08-12,买单执行,4045.80
# 2015-08-19,卖单执行,3729.528650
# 2015-08-20,卖单执行,3829.158000
# 毛收益 -8023.75, 扣佣后收益 -8064.23 , 佣金 40.47
# 2015-09-10,买单执行,3366.03
# 2015-09-11,卖单执行,3333.130600
# 毛收益 -953.98, 扣佣后收益 -992.83 , 佣金 38.86
# 2015-10-14,买单执行,3448.30
# 2015-10-22,卖单执行,3442.310000
# 2015-10-23,卖单执行,3519.155800
# 毛收益 -90.75, 扣佣后收益 -129.36 , 佣金 38.60
# 2015-11-06,买单执行,3716.83
# 2015-11-17,卖单执行,3771.477850
# 毛收益 1420.80, 扣佣后收益  1381.86 , 佣金 38.94
# 2015-12-21,买单执行,3780.91
# 2015-12-29,卖单执行,3710.480000
# 2015-12-30,卖单执行,3744.095450
# 毛收益 -1797.58, 扣佣后收益 -1836.54 , 佣金 38.96
# 2016-02-18,买单执行,3093.51
# 2016-02-26,卖单执行,2927.389500
# 2016-02-29,卖单执行,2924.882100
# 毛收益 -5154.75, 扣佣后收益 -5192.08 , 佣金 37.33
# 2016-03-08,买单执行,3109.25
# 2016-03-14,卖单执行,3034.000000
# 毛收益 -2182.25, 扣佣后收益 -2217.88 , 佣金 35.63
# 2016-03-22,买单执行,3247.77
# 2016-03-29,卖单执行,3155.453450
# 毛收益 -2492.49, 扣佣后收益 -2527.07 , 佣金 34.58
# 2016-06-02,买单执行,3168.82
# 2016-06-14,卖单执行,3055.660000
# 2016-06-15,卖单执行,3042.230000
# 毛收益 -3068.75, 扣佣后收益 -3102.36 , 佣金 33.61
# 2016-07-08,买单执行,3204.93
# 2016-07-21,卖单执行,3238.300000
# 2016-07-22,卖单执行,3234.983800
# 毛收益 864.30, 扣佣后收益  830.80 , 佣金 33.50
# 2016-08-11,买单执行,3255.76
# 2016-08-24,卖单执行,3325.220350
# 毛收益 1736.56, 扣佣后收益  1703.66 , 佣金 32.90
# 2016-10-13,买单执行,3307.41
# 2016-11-01,卖单执行,3334.460000
# 毛收益 703.30, 扣佣后收益  668.76 , 佣金 34.54
# 2016-11-02,买单执行,3356.40
# 2016-11-03,卖单执行,3324.840000
# 毛收益 -789.00, 扣佣后收益 -822.41 , 佣金 33.41
# 2016-11-09,买单执行,3373.10
# 2016-12-06,卖单执行,3456.810000
# 毛收益 2092.75, 扣佣后收益  2058.60 , 佣金 34.15
# 2017-01-06,买单执行,3368.87
# 2017-01-13,卖单执行,3309.370000
# 毛收益 -1547.00, 扣佣后收益 -1581.73 , 佣金 34.73
# 2017-01-26,买单执行,3395.15
# 2017-02-28,卖单执行,3441.360000
# 毛收益 1155.22, 扣佣后收益  1121.03 , 佣金 34.18
# 2017-04-10,买单执行,3522.80
# 2017-04-17,卖单执行,3458.361300
# 毛收益 -1546.53, 扣佣后收益 -1580.04 , 佣金 33.51
# 2017-05-18,买单执行,3404.61
# 2017-06-20,卖单执行,3542.986050
# 毛收益 3459.44, 扣佣后收益  3424.70 , 佣金 34.74
# 2017-06-26,买单执行,3645.16
# 2017-07-06,卖单执行,3636.287200
# 毛收益 -212.83, 扣佣后收益 -247.78 , 佣金 34.95
# 2017-07-14,买单执行,3701.03
# 2017-08-01,卖单执行,3737.100000
# 毛收益 865.61, 扣佣后收益  829.90 , 佣金 35.70
# 2017-08-03,买单执行,3766.35
# 2017-08-10,卖单执行,3706.335200
# 毛收益 -1380.34, 扣佣后收益 -1414.71 , 佣金 34.37
# 2017-08-23,买单执行,3766.35
# 2017-09-08,卖单执行,3813.980000
# 毛收益 1095.53, 扣佣后收益  1060.67 , 佣金 34.87
# 2017-10-13,买单执行,3927.17
# 2017-11-28,卖单执行,4014.038950
# 毛收益 1911.12, 扣佣后收益  1876.18 , 佣金 34.94
# 2017-12-27,买单执行,4047.74
# 2017-12-29,卖单执行,4012.870000
# 毛收益 -767.14, 扣佣后收益 -802.61 , 佣金 35.47
# 2018-01-08,买单执行,4161.55
# 2018-01-31,卖单执行,4232.770000
# 毛收益 1495.53, 扣佣后收益  1460.27 , 佣金 35.26
# 2018-02-28,买单执行,4036.87
# 2018-03-06,卖单执行,4014.815050
# 毛收益 -485.30, 扣佣后收益 -520.72 , 佣金 35.43
# 2018-03-13,买单执行,4130.28
# 2018-03-20,卖单执行,4040.310000
# 毛收益 -1979.34, 扣佣后收益 -2015.29 , 佣金 35.95
# 2018-05-14,买单执行,3906.30
# 2018-05-18,卖单执行,3841.900000
# 毛收益 -1416.90, 扣佣后收益 -1450.99 , 佣金 34.09
# 2018-07-17,买单执行,3467.19
# 2018-07-19,卖单执行,3427.576000
# 毛收益 -990.35, 扣佣后收益 -1024.82 , 佣金 34.47
# 2018-07-25,买单执行,3589.98
# 2018-08-02,卖单执行,3417.178250
# 2018-08-03,卖单执行,3349.826700
# 毛收益 -4214.59, 扣佣后收益 -4248.21 , 佣金 33.62
# 2018-08-29,买单执行,3398.71
# 2018-09-03,卖单执行,3304.086550
# 毛收益 -2270.96, 扣佣后收益 -2303.14 , 佣金 32.17
# 2018-09-21,买单执行,3337.30
# 2018-10-09,卖单执行,3276.130000
# 2018-10-10,卖单执行,3278.952850
# 毛收益 -1465.34, 扣佣后收益 -1497.09 , 佣金 31.75
# 2018-10-24,买单执行,3185.31
# 2018-10-29,卖单执行,3141.702550
# 毛收益 -1046.51, 扣佣后收益 -1076.88 , 佣金 30.37
# 2018-11-06,买单执行,3254.98
# 2018-11-07,卖单执行,3227.660600
# 毛收益 -628.35, 扣佣后收益 -658.17 , 佣金 29.82
# 2018-11-08,买单执行,3253.57
# 2018-11-14,卖单执行,3217.471800
# 毛收益 -830.26, 扣佣后收益 -860.03 , 佣金 29.77
# 2018-11-21,买单执行,3203.04
# 2018-11-22,卖单执行,3216.805150
# 毛收益 316.70, 扣佣后收益  287.17 , 佣金 29.53
# 2018-12-05,买单执行,3240.38
# 2018-12-10,卖单执行,3137.752400
# 毛收益 -2360.46, 扣佣后收益 -2389.80 , 佣金 29.34
# 2019-01-09,买单执行,3080.56
# 2019-01-31,卖单执行,3178.010000
# 毛收益 2338.89, 扣佣后收益  2308.85 , 佣金 30.04
# 2019-02-11,买单执行,3256.01
# 2019-03-11,卖单执行,3650.810000
# 毛收益 9080.42, 扣佣后收益  9048.65 , 佣金 31.77
# 2019-03-25,买单执行,3795.32
# 2019-03-26,卖单执行,3747.697350
# 毛收益 -1047.75, 扣佣后收益 -1080.94 , 佣金 33.19
# 2019-04-03,买单执行,3967.61
# 2019-04-16,卖单执行,3943.490000
# 2019-04-17,卖单执行,4060.316400
# 毛收益 -389.68, 扣佣后收益 -422.93 , 佣金 33.25
# 2019-06-13,买单执行,3697.59
# 2019-07-09,卖单执行,3779.109500
# 毛收益 1793.43, 扣佣后收益  1760.53 , 佣金 32.90
# 2019-07-30,买单执行,3880.88
# 2019-08-05,卖单执行,3705.787950
# 毛收益 -3851.98, 扣佣后收益 -3885.36 , 佣金 33.38
# 2019-08-20,买单执行,3799.90
# 2019-09-02,卖单执行,3799.820000
# 毛收益 -1.68, 扣佣后收益 -33.60 , 佣金 31.92
# 2019-09-03,买单执行,3856.68
# 2019-09-18,卖单执行,3902.510000
# 2019-09-19,卖单执行,3904.340200
# 毛收益 964.26, 扣佣后收益  931.67 , 佣金 32.59
# 2019-10-17,买单执行,3935.81
# 2019-10-22,卖单执行,3876.828450
# 毛收益 -1238.61, 扣佣后收益 -1271.43 , 佣金 32.81
# 2019-11-05,买单执行,4002.03
# 2019-11-13,卖单执行,3885.753600
# 毛收益 -2325.54, 扣佣后收益 -2357.09 , 佣金 31.55
# 2019-12-11,买单执行,3909.39
# 2019-12-26,卖单执行,3993.540000
# 毛收益 1683.00, 扣佣后收益  1651.39 , 佣金 31.61
# 2020-01-02,买单执行,4141.96
# 2020-01-14,卖单执行,4194.084200
# 毛收益 990.42, 扣佣后收益  958.74 , 佣金 31.68
# 2020-02-13,买单执行,3999.55
# 2020-02-27,卖单执行,4067.440000
# 毛收益 1357.80, 扣佣后收益  1325.53 , 佣金 32.27
# 2020-04-03,买单执行,3738.83
# 2020-04-07,卖单执行,3772.210000
# 毛收益 734.36, 扣佣后收益  701.31 , 佣金 33.05
# 2020-04-09,买单执行,3801.72
# 2020-04-27,卖单执行,3793.770000
# 2020-04-28,卖单执行,3816.173250
# 毛收益 -152.50, 扣佣后收益 -185.92 , 佣金 33.42
# 2020-05-06,买单执行,3886.60
# 2020-05-18,卖单执行,3898.400000
# 毛收益 247.88, 扣佣后收益  215.18 , 佣金 32.70
# 2020-06-04,买单执行,3999.81
# 2020-06-16,卖单执行,3987.860000
# 2020-06-17,卖单执行,3998.516950
# 毛收益 -240.29, 扣佣后收益 -273.84 , 佣金 33.55
# 2020-06-23,买单执行,4118.53
# 2020-07-16,卖单执行,4717.822350
# 2020-07-17,卖单执行,4502.146150
# 毛收益 11770.17, 扣佣后收益  11734.86 , 佣金 35.30
# 2020-08-05,买单执行,4785.57
# 2020-08-10,卖单执行,4658.351200
# 毛收益 -2417.13, 扣佣后收益 -2453.02 , 佣金 35.89
# 2020-09-02,买单执行,4863.55
# 2020-09-04,卖单执行,4726.560000
# 毛收益 -2602.81, 扣佣后收益 -2639.25 , 佣金 36.44
# 2020-09-22,买单执行,4677.49
# 2020-09-23,卖单执行,4623.550000
# 毛收益 -1024.88, 扣佣后收益 -1060.22 , 佣金 35.34
# 2020-10-14,买单执行,4830.46
# 2020-10-22,卖单执行,4756.697000
# 毛收益 -1327.73, 扣佣后收益 -1362.25 , 佣金 34.51
# 2020-11-09,买单执行,4943.45
# 2020-11-16,卖单执行,4856.555200
# 毛收益 -1477.28, 扣佣后收益 -1510.60 , 佣金 33.32
# 2020-11-25,买单执行,5004.77
# 2020-11-26,卖单执行,4883.778400
# 毛收益 -2056.86, 扣佣后收益 -2090.48 , 佣金 33.62
# 2020-12-03,买单执行,5072.30
# 2020-12-10,卖单执行,4919.770000
# 毛收益 -2440.48, 扣佣后收益 -2472.45 , 佣金 31.97
# 2020-12-23,买单执行,5002.19
# 2021-01-18,卖单执行,5410.969200
# 毛收益 6540.52, 扣佣后收益  6507.20 , 佣金 33.32
# 2021-02-10,买单执行,5738.23
# 2021-02-23,卖单执行,5541.110000
# 2021-02-24,卖单执行,5563.522600
# 毛收益 -2934.36, 扣佣后收益 -2968.21 , 佣金 33.84
# 2021-04-06,买单执行,5181.15
# 2021-04-12,卖单执行,5001.845100
# 毛收益 -2868.88, 扣佣后收益 -2901.46 , 佣金 32.59
# 2021-04-22,买单执行,5119.22
# 2021-05-07,卖单执行,5048.092700
# 毛收益 -1138.04, 扣佣后收益 -1170.57 , 佣金 32.54
# 2021-05-20,买单执行,5192.89
# 2021-06-04,卖单执行,5221.230000
# 毛收益 425.17, 扣佣后收益  393.93 , 佣金 31.24
# 2021-06-28,买单执行,5260.64
# 2021-07-05,卖单执行,5048.411100
# 毛收益 -3183.43, 扣佣后收益 -3214.36 , 佣金 30.93
# 2021-08-06,买单执行,4944.35
# 2021-08-16,卖单执行,4931.370000
# 毛收益 -194.70, 扣佣后收益 -224.33 , 佣金 29.63
# 2021-09-08,买单执行,5011.73
# 2021-09-16,卖单执行,4842.456050
# 毛收益 -2539.17, 扣佣后收益 -2568.73 , 佣金 29.56
# 2021-12-08,买单执行,4959.08
# 2021-12-20,卖单执行,4910.295150
# 毛收益 -731.80, 扣佣后收益 -761.41 , 佣金 29.61
# end portfolio value: 75022.9336981102

# %%
#画图仍只能在notebook中输出(将basic改成full的话可以得到更多的输出结果，但其中一个return distribution的表会报错)
qs.reports.basic(returns,rf=0.0,grayscale=False,display=True,compounded = True)
#只有在full中有和benchmark的对比
qs.reports.full(returns,benchmark=stock_df['close'],rf=0.0,grayscale=False,display=True,compounded = True)
# Out:
# <h4>Performance Metrics</h4>
#                     Strategy
# ------------------  ----------
# Start Period        2014-03-07
# End Period          2021-12-30
# Risk-Free Rate      0.0%
# Time in Market      43.0%
#
# Cumulative Return   -24.98%
# CAGR﹪              -3.61%
#
# Sharpe              -0.27
# Sortino             -0.38
# Sortino/√2          -0.27
# Omega               0.93
#
# Max Drawdown        -38.59%
# Longest DD Days     2438
#
# Gain/Pain Ratio     -0.07
# Gain/Pain (1M)      -0.18
#
# Payoff Ratio        1.27
# Profit Factor       0.93
# Common Sense Ratio  1.0
# CPC Index           0.5
# Tail Ratio          1.08
# Outlier Win Ratio   11.45
# Outlier Loss Ratio  3.18
#
# MTD                 -1.0%
# 3M                  -1.0%
# 6M                  -7.06%
# YTD                 -12.01%
# 1Y                  -9.14%
# 3Y (ann.)           0.28%
# 5Y (ann.)           -3.15%
# 10Y (ann.)          -3.61%
# All-time (ann.)     -3.61%
#
# Avg. Drawdown       -9.29%
# Avg. Drawdown Days  353
# Recovery Factor     -0.65
# Ulcer Index         0.26
# Serenity Index      -0.02
# <h4>Strategy Visualization</h4>
# <h4>Performance Metrics</h4>
#                            Strategy    Benchmark
# -------------------------  ----------  -----------
# Start Period               2014-03-07  2014-03-07
# End Period                 2021-12-30  2021-12-30
# Risk-Free Rate             0.0%        0.0%
# Time in Market             43.0%       100.0%
#
# Cumulative Return          -24.98%     126.97%
# CAGR﹪                     -3.61%      11.05%
#
# Sharpe                     -0.27       0.58
# Smart Sharpe               -0.25       0.55
# Sortino                    -0.38       0.8
# Smart Sortino              -0.35       0.75
# Sortino/√2                 -0.27       0.57
# Smart Sortino/√2           -0.25       0.53
# Omega                      0.93        0.93
#
# Max Drawdown               -38.59%     -46.7%
# Longest DD Days            2438        2037
# Volatility (ann.)          11.69%      23.13%
# R^2                        0.26        0.26
# Calmar                     -0.09       0.24
# Skew                       -0.19       -0.75
# Kurtosis                   18.23       5.68
#
# Expected Daily %           -0.02%      0.04%
# Expected Monthly %         -0.31%      0.88%
# Expected Yearly %          -3.53%      10.79%
# Kelly Criterion            -8.2%       12.98%
# Risk of Ruin               0.0%        0.0%
# Daily Value-at-Risk        -1.22%      -2.34%
# Expected Shortfall (cVaR)  -1.22%      -2.34%
#
# Gain/Pain Ratio            -0.07       0.12
# Gain/Pain (1M)             -0.18       0.66
#
# Payoff Ratio               1.15        1.16
# Profit Factor              0.93        1.12
# Common Sense Ratio         1.0         1.21
# CPC Index                  0.45        0.69
# Tail Ratio                 1.08        1.08
# Outlier Win Ratio          14.68       3.12
# Outlier Loss Ratio         5.1         3.52
#
# MTD                        -1.0%       1.85%
# 3M                         -1.0%       0.77%
# 6M                         -7.06%      -5.18%
# YTD                        -12.01%     -5.56%
# 1Y                         -9.14%      -2.41%
# 3Y (ann.)                  0.28%       17.84%
# 5Y (ann.)                  -3.15%      8.27%
# 10Y (ann.)                 -3.61%      11.05%
# All-time (ann.)            -3.61%      11.05%
#
# Best Day                   5.82%       6.71%
# Worst Day                  -6.76%      -8.75%
# Best Month                 17.17%      25.81%
# Worst Month                -7.59%      -21.04%
# Best Year                  8.94%       62.97%
# Worst Year                 -17.97%     -25.31%
#
# Avg. Drawdown              -9.29%      -4.53%
# Avg. Drawdown Days         353         88
# Recovery Factor            -0.65       2.72
# Ulcer Index                0.26        0.27
# Serenity Index             -0.02       0.15
#
# Avg. Up Month              3.88%       6.72%
# Avg. Down Month            -3.32%      -3.63%
# Win Days %                 42.2%       53.33%
# Win Month %                39.51%      60.64%
# Win Quarter %              40.62%      59.38%
# Win Year %                 50.0%       62.5%
# Beta                       0.26        -
# Alpha                      -0.07       -
# None
# <h4>5 Worst Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2015-04-28  2019-01-14  2021-12-30  2438    -38.593267        -38.056067
# 2  2014-03-10  2014-07-11  2014-12-05   270    -14.727919        -14.397317
# 3  2014-12-23  2015-02-25  2015-04-08   106    -12.015355        -11.956080
# 4  2014-12-09  2014-12-09  2014-12-16     7     -4.477777         -2.143333
# 5  2015-04-20  2015-04-20  2015-04-21     1     -1.608734          0.000000
# <h4>Strategy Visualization</h4>
